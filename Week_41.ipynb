# %% [markdown]
# <!-- HTML file automatically generated from DocOnce source (https://github.com/doconce/doconce/)
# doconce format html exercisesweek41.do.txt  -->
# <!-- dom:TITLE: Exercises week 41 -->

# %% [markdown]
# # Exercises week 41
#
# **October 6-10, 2025**
#
# Date: **Deadline is Friday October 10 at midnight**

# %% [markdown]
# # Overarching aims of the exercises this week
#
# This week, you will implement the entire feed-forward pass of a neural network! Next week you will compute the gradient of the network by implementing back-propagation manually, and by using autograd which does back-propagation for you (much easier!). Next week, you will also use the gradient to optimize the network with a gradient method! However, there is an optional exercise this week to get started on training the network and getting good results!
#
# We recommend that you do the exercises this week by editing and running this notebook file, as it includes some checks along the way that you have implemented the pieces of the feed-forward pass correctly, and running small parts of the code at a time will be important for understanding the methods.
#
# If you have trouble running a notebook, you can run this notebook in google colab instead (https://colab.research.google.com/drive/1zKibVQf-iAYaAn2-GlKfgRjHtLnPlBX4#offline=true&sandboxMode=true), an updated link will be provided on the course discord (you can also send an email to k.h.fredly@fys.uio.no if you encounter any trouble), though we recommend that you set up VSCode and your python environment to run code like this locally.
#
# First, here are some functions you are going to need, don't change this cell. If you are unable to import autograd, just swap in normal numpy until you want to do the final optional exercise.

# %%
import autograd.numpy as np  # We need to use this numpy wrapper to make automatic differentiation work later
from sklearn import datasets
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score


# Defining some activation functions
def ReLU(z):
    return np.where(z > 0, z, 0)


def sigmoid(z):
    return 1 / (1 + np.exp(-z))


def softmax(z):
    """Compute softmax values for each set of scores in the rows of the matrix z.
    Used with batched input data."""
    e_z = np.exp(z - np.max(z, axis=0))
    return e_z / np.sum(e_z, axis=1)[:, np.newaxis]


def softmax_vec(z):
    """Compute softmax values for each set of scores in the vector z.
    Use this function when you use the activation function on one vector at a time"""
    e_z = np.exp(z - np.max(z))
    return e_z / np.sum(e_z)

# %% [markdown]
# # Exercise 1
#
# In this exercise you will compute the activation of the first layer. You only need to change the code in the cells right below an exercise, the rest works out of the box. Feel free to make changes and see how stuff works though!

# %%
np.random.seed(2024)

num_inputs = 2
layer_1 = 4

x = np.random.randn(num_inputs)  # network input. This is a single input with two features
W1 = np.random.randn(layer_1, num_inputs)  # first layer weights

# %% [markdown]
# **a)** Given the shape of the first layer weight matrix, what is the input shape of the neural network? What is the output shape of the first layer?

# %% [markdown]
# The input shape of the matrix vector with lenght 2.
#
# The shape of the first layer is a vector with length 4.

# %% [markdown]
# **b)** Define the bias of the first layer, `b1`with the correct shape. (Run the next cell right after the previous to get the random generated values to line up with the test solution below)

# %%
# W1.shape[0] length of vector W1 @ x will be [4,2] @ [2,1] = [4,1] 
b1 = np.random.randn(layer_1)

# %% [markdown]
# **c)** Compute the intermediary `z1` for the first layer

# %%
z1 = W1 @ x + b1
print(z1)
# Out:
# [ 0.60610368  4.0076268  -6.84805855  0.56469864]

# %% [markdown]
# **d)** Compute the activation `a1` for the first layer using the ReLU activation function defined earlier.

# %%
a1 = ReLU(z1)

# %% [markdown]
# Confirm that you got the correct activation with the test below. Make sure that you define `b1` with the randn function right after you define `W1`.

# %%
sol1 = np.array([0.60610368, 4.0076268, 0.0, 0.56469864])

print(np.allclose(a1, sol1))
# Out:
# True

# %% [markdown]
# # Exercise 2
#
# Now we will add a layer to the network with an output of length 8 and ReLU activation.
#
# **a)** What is the input of the second layer? What is its shape?

# %% [markdown]
# The input for the second layer is the output from previous z1 layer. It is a vector with lenght 4.

# %% [markdown]
# **b)** Define the weight and bias of the second layer with the right shapes.

# %%
layer_2 = 8

W2 = np.random.randn(layer_2, layer_1)
b2 = np.random.randn(layer_2)

# %% [markdown]
# **c)** Compute the intermediary `z2` and activation `a2` for the second layer.

# %%
z2 = W2 @ z1 + b2
a2 = ReLU(z2)

# %% [markdown]
# Confirm that you got the correct activation shape with the test below.

# %%
print(
    np.allclose(np.exp(len(a2)), 2980.9579870417283)
)  # This should evaluate to True if a2 has the correct shape :)
# Out:
# True

# %% [markdown]
# # Exercise 3
#
# We often want our neural networks to have many layers of varying sizes. To avoid writing very long and error-prone code where we explicitly define and evaluate each layer we should keep all our layers in a single variable which is easy to create and use.
#
# **a)** Complete the function below so that it returns a list `layers` of weight and bias tuples `(W, b)` for each layer, in order, with the correct shapes that we can use later as our network parameters.

# %%
def create_layers(network_input_size, layer_output_sizes):
    layers = []
    i_size = network_input_size
    
    for layer_output_size in layer_output_sizes:
        W = np.random.randn(layer_output_size, i_size)
        b = np.random.randn(layer_output_size)
        layers.append((W, b))

        i_size = layer_output_size
    return layers

# %% [markdown]
# **b)** Comple the function below so that it evaluates the intermediary `z` and activation `a` for each layer, with ReLU actication, and returns the final activation `a`. This is the complete feed-forward pass, a full neural network!

# %%
def feed_forward_all_relu(layers, input):
    a = input
    for W, b in layers:
        z = W @ a + b
        a = ReLU(z)
    return a

# %% [markdown]
# **c)** Create a network with input size 8 and layers with output sizes 10, 16, 6, 2. Evaluate it and make sure that you get the correct size vectors along the way.

# %%
np.random.seed(2024)

input_size = 8
layer_output_sizes = [10, 16, 6, 2]

x = np.random.rand(input_size)
layers = create_layers(input_size, layer_output_sizes)
predict = feed_forward_all_relu(layers, x)
print('The output is: ',predict, '\n')

index = 1
for i in layers:
    print(f" For layer #{index} the size is: {len(i[0])}")
    index += 1
# Out:
# The output is:  [10.97402184  0.        ]
#
#  For layer #1 the size is: 10
#  For layer #2 the size is: 16
#  For layer #3 the size is: 6
#  For layer #4 the size is: 2

# %% [markdown]
# **d)** Why is a neural network with no activation functions always mathematically equivelent to a neural network with only one layer?

# %% [markdown]
# Without activation function every next layer of the network will be a linear tranformation of the previous layer or input.
# The combination of linear transformations can be combined into 1 linear transfortmaton, making it equivalent to a neural network with 1 layer without an activation function.

# %% [markdown]
# # Exercise 4 - Custom activation for each layer

# %% [markdown]
# So far, every layer has used the same activation, ReLU. We often want to use other types of activation however, so we need to update our code to support multiple types of activation functions. Make sure that you have completed every previous exercise before trying this one.

# %% [markdown]
# **a)** Complete the `feed_forward` function which accepts a list of activation functions as an argument, and which evaluates these activation functions at each layer.

# %%
def feed_forward(input, layers, activation_funcs):
    a = input
    for (W, b), activation_func in zip(layers, activation_funcs):
        z = W @ a + b
        a = activation_func(z)
    return a

# %% [markdown]
# **b)** You are now given a list with three activation functions, two ReLU and one sigmoid. (Don't call them yet! you can make a list with function names as elements, and then call these elements of the list later. If you add other functions than the ones defined at the start of the notebook, make sure everything is defined using autograd's numpy wrapper, like above, since we want to use automatic differentiation on all of these functions later.)
#
# "Evaluate a network with three layers and these activation functions.

# %%
network_input_size = 8
layer_output_sizes = [10, 16, 6, 2]
activation_funcs = [ReLU, ReLU, sigmoid]
layers = create_layers(input_size, layer_output_sizes)

np.random.seed(42)
x = np.random.randn(network_input_size)
feed_forward(x, layers, activation_funcs)
# Out:
# array([1.05162482e-06, 9.97916767e-01, 1.78812314e-06, 7.51797269e-04,
#        2.23653172e-02, 9.99996964e-01])

# %% [markdown]
# **c)** How does the output of the network change if you use sigmoid in the hidden layers and ReLU in the output layer?

# %%
activation_funcs_2 = [sigmoid, sigmoid, ReLU]
feed_forward(x, layers, activation_funcs_2)
# Out:
# array([0.        , 2.30450746, 0.        , 0.        , 0.        ,
#        5.23478487])

# %% [markdown]
# With this sequence of activation functions, where RelU is the last one, we get outputs within the range from 0 to 5.20390277 (for seed 42), whereas with ReLU, ReLU, sigmoid, we got all values within the range [0, 1].
#
# This happened due to the behaviour of activation functions. Relu takes negative values and returns 0, and keep the rest as it is, while sigmoid scales all values into a new one within the  range [0, 1].

# %% [markdown]
# # Exercise 5 - Processing multiple inputs at once

# %% [markdown]
# So far, the feed forward function has taken one input vector as an input. This vector then undergoes a linear transformation and then an element-wise non-linear operation for each layer. This approach of sending one vector in at a time is great for interpreting how the network transforms data with its linear and non-linear operations, but not the best for numerical efficiency. Now, we want to be able to send many inputs through the network at once. This will make the code a bit harder to understand, but it will make it faster, and more compact. It will be worth the trouble.
#
# To process multiple inputs at once, while still performing the same operations, you will only need to flip a couple things around.

# %% [markdown]
# **a)** Complete the function `create_layers_batch` so that the weight matrix is the transpose of what it was when you only sent in one input at a time.

# %%
def create_layers_batch(network_input_size, layer_output_sizes):
    layers = []
    i_size = network_input_size
    
    for layer_output_size in layer_output_sizes:
        W = np.random.randn(layer_output_size, i_size)
        W = W.T
        b = np.random.randn(layer_output_size)
        layers.append((W, b))

        i_size = layer_output_size
    return layers

# %% [markdown]
# **b)** Make a matrix of inputs with the shape (number of features, number of inputs), you choose the number of inputs and features per input. Then complete the function `feed_forward_batch` so that you can process this matrix of inputs with only one matrix multiplication and one broadcasted vector addition per layer. (Hint: You will only need to swap two variable around from your previous implementation, but remember to test that you get the same results for equivelent inputs!)

# %%
inputs = np.random.rand(1000, 4)

def feed_forward_batch(inputs, layers, activation_funcs):
    a = inputs
    for (W, b), activation_func in zip(layers, activation_funcs):
        #print(a.shape)
        #print(W.shape)
        z = a @ W + b
        a = activation_func(z)
    return a

# %% [markdown]
# **c)** Create and evaluate a neural network with 4 inputs and layers with output sizes 12, 10, 3 and activations ReLU, ReLU, softmax.

# %%
network_input_size = 4
layer_output_sizes = [12, 10, 3]
activation_funcs = [ReLU, ReLU, softmax]
layers = create_layers_batch(network_input_size, layer_output_sizes)

x = np.random.randn(7, network_input_size)

feed_forward_batch(x, layers, activation_funcs)
# Out:
# array([[7.55160437e-04, 9.99244694e-01, 1.45853828e-07],
#        [1.90763721e-03, 9.76041890e-01, 2.20504726e-02],
#        [4.99998620e-01, 2.75926197e-06, 4.99998620e-01],
#        [9.93451413e-01, 3.18686853e-03, 3.36171870e-03],
#        [8.44790714e-02, 9.15520872e-01, 5.68071803e-08],
#        [9.88809193e-01, 4.74833152e-03, 6.44247570e-03],
#        [9.98519417e-01, 5.70090493e-04, 9.10492107e-04]])

# %% [markdown]
# You should use this batched approach moving forward, as it will lead to much more compact code. However, remember that each input is still treated separately, and that you will need to keep in mind the transposed weight matrix and other details when implementing backpropagation.

# %% [markdown]
# # Exercise 6 - Predicting on real data

# %% [markdown]
# You will now evaluate your neural network on the iris data set (https://scikit-learn.org/1.5/auto_examples/datasets/plot_iris_dataset.html).
#
# This dataset contains data on 150 flowers of 3 different types which can be separated pretty well using the four features given for each flower, which includes the width and length of their leaves. You are will later train your network to actually make good predictions.

# %%
iris = datasets.load_iris()

_, ax = plt.subplots()
scatter = ax.scatter(iris.data[:, 0], iris.data[:, 1], c=iris.target)
ax.set(xlabel=iris.feature_names[0], ylabel=iris.feature_names[1])
_ = ax.legend(
    scatter.legend_elements()[0], iris.target_names, loc="lower right", title="Classes"
)

# %%
inputs = iris.data

# Since each prediction is a vector with a score for each of the three types of flowers,
# we need to make each target a vector with a 1 for the correct flower and a 0 for the others.
targets = np.zeros((len(iris.data), 3))
for i, t in enumerate(iris.target):
    targets[i, t] = 1


def accuracy(predictions, targets):
    one_hot_predictions = np.zeros(predictions.shape)

    for i, prediction in enumerate(predictions):
        one_hot_predictions[i, np.argmax(prediction)] = 1
    return accuracy_score(one_hot_predictions, targets)

# %% [markdown]
# **a)** What should the input size for the network be with this dataset? What should the output size of the last layer be?

# %% [markdown]
# Because we have dataset contains data on 150 flowers with 4 columns being: Sepal Length, Sepal Width, Petal Length and Petal Width,the input size for the network will be [150, 4]. The output size will be [150, 3] because we can have 3 different classes of irises and 150 samples.

# %% [markdown]
# **b)** Create a network with two hidden layers, the first with sigmoid activation and the last with softmax, the first layer should have 8 "nodes", the second has the number of nodes you found in exercise a). Softmax returns a "probability distribution", in the sense that the numbers in the output are positive and add up to 1 and, their magnitude are in some sense relative to their magnitude before going through the softmax function. Remember to use the batched version of the create_layers and feed forward functions.

# %%
network_input_size = len(inputs[0])
layer_output_sizes = [8, 3]
activation_funcs = [sigmoid, softmax]
layers = create_layers_batch(network_input_size, layer_output_sizes)

# %% [markdown]
# **c)** Evaluate your model on the entire iris dataset! For later purposes, we will split the data into train and test sets, and compute gradients on smaller batches of the training data. But for now, evaluate the network on the whole thing at once.

# %%
predictions = feed_forward_batch(inputs, layers, activation_funcs)
# Out:
# [[2.19828669e-03 6.47176008e-02 9.99938127e-01 ... 9.05455521e-01
#   9.99804527e-01 2.19790404e-03]
#  [3.30909697e-03 1.33952954e-01 9.99898094e-01 ... 8.93601083e-01
#   9.99619812e-01 3.13118547e-03]
#  [3.28505824e-03 8.22857450e-02 9.99862693e-01 ... 8.96603021e-01
#   9.99594474e-01 3.54596518e-03]
#  ...
#  [2.26897294e-03 9.64438357e-01 9.99999927e-01 ... 6.26331781e-01
#   9.97212225e-01 7.61556253e-05]
#  [2.33562182e-03 9.40080906e-01 9.99999935e-01 ... 6.00218612e-01
#   9.95590779e-01 6.62332128e-05]
#  [2.88799119e-03 9.47471798e-01 9.99999794e-01 ... 5.92448917e-01
#   9.93712887e-01 1.41540250e-04]]
# [[0.15065147 0.58335691 0.26599162]
#  [0.16565093 0.55491654 0.27943254]
#  [0.15410065 0.57662024 0.2692791 ]
#  [0.16027932 0.56385338 0.2758673 ]
#  [0.14800008 0.58829558 0.26370434]
#  [0.14807139 0.58783808 0.26409053]
#  [0.14998447 0.58380532 0.26621021]
#  [0.15388334 0.57652045 0.26959621]
#  [0.16408723 0.55722603 0.27868674]
#  [0.16304239 0.55919872 0.27775889]
#  [0.14931931 0.58606744 0.26461325]
#  [0.15383311 0.57572456 0.27044233]
#  [0.16380789 0.55820817 0.27798394]
#  [0.15312481 0.57944192 0.26743327]
#  [0.1441822  0.59798779 0.25783001]
#  [0.14196946 0.60141506 0.25661548]
#  [0.14489733 0.59569312 0.25940955]
#  [0.15098755 0.58277834 0.26623411]
#  [0.15169875 0.58136863 0.26693262]
#  [0.14624047 0.59154446 0.26221507]
#  [0.16133707 0.5623321  0.27633082]
#  [0.14820705 0.58780411 0.26398884]
#  [0.14340887 0.59840747 0.25818366]
#  [0.16400028 0.55711231 0.27888741]
#  [0.15926106 0.5637138  0.27702514]
#  [0.17288264 0.54087674 0.28624062]
#  [0.15643262 0.57136885 0.27219853]
#  [0.1526634  0.57923307 0.26810353]
#  [0.15389323 0.57734987 0.2687569 ]
#  [0.15959615 0.56469708 0.27570676]
#  [0.16496478 0.55492016 0.28011507]
#  [0.15824377 0.56928828 0.27246794]
#  [0.14264035 0.59876086 0.25859879]
#  [0.14237751 0.60036335 0.25725914]
#  [0.16365557 0.55805482 0.27828961]
#  [0.15490498 0.5759894  0.26910562]
#  [0.15197539 0.58197942 0.26604519]
#  [0.14721352 0.58963847 0.26314802]
#  [0.1578457  0.5693107  0.2728436 ]
#  [0.15468651 0.57518596 0.27012752]
#  [0.14919307 0.5864842  0.26432273]
#  [0.20409039 0.48810871 0.3078009 ]
#  [0.15178591 0.58068859 0.26752551]
#  [0.15421323 0.5758782  0.26990857]
#  [0.15053437 0.5813394  0.26812624]
#  [0.16506618 0.55584638 0.27908744]
#  [0.14682618 0.58984509 0.26332873]
#  [0.15489223 0.57448615 0.27062162]
#  [0.14875153 0.58696459 0.26428388]
#  [0.15521883 0.57447751 0.27030366]
#  [0.3695503  0.25542293 0.37502676]
#  [0.35496549 0.27847378 0.36656073]
#  [0.370977   0.26012823 0.36889476]
#  [0.36457794 0.27390796 0.3615141 ]
#  [0.37083172 0.26418972 0.36497856]
#  [0.35439272 0.28646116 0.35914612]
#  [0.35003289 0.29138639 0.35858072]
#  [0.33423486 0.29809717 0.36766797]
#  [0.37082479 0.25583835 0.37333685]
#  [0.33921757 0.30600813 0.35477431]
#  [0.36258613 0.26765027 0.3697636 ]
#  [0.34769268 0.29105215 0.36125517]
#  [0.37675746 0.24648509 0.37675746]
#  [0.36029247 0.27972468 0.35998284]
#  [0.3273819  0.30814871 0.36446939]
#  [0.36451866 0.26206222 0.37341912]
#  [0.34240948 0.30914433 0.3484462 ]
#  [0.35806754 0.26662437 0.37530808]
#  [0.37277624 0.27288529 0.35433847]
#  [0.36013176 0.26817077 0.37169747]
#  [0.34093609 0.32531319 0.33375073]
#  [0.35928262 0.26923263 0.37148474]
#  [0.36615593 0.28475875 0.34908532]
#  [0.36379957 0.26881457 0.36738586]
#  [0.36532251 0.2614282  0.37324929]
#  [0.36661323 0.26093073 0.37245603]
#  [0.37531267 0.25471818 0.36996915]
#  [0.36686    0.27935771 0.35378229]
#  [0.35752529 0.28458501 0.3578897 ]
#  [0.34781886 0.27837611 0.37380504]
#  [0.36099028 0.26787449 0.37113523]
#  [0.35948181 0.26649691 0.37402127]
#  [0.3554244  0.27340539 0.37117021]
#  [0.35168071 0.31848186 0.32983742]
#  [0.33582875 0.32167432 0.34249693]
#  [0.33164678 0.31361335 0.35473987]
#  [0.36716095 0.26425047 0.36858858]
#  [0.37692583 0.25516456 0.36790961]
#  [0.33654844 0.30026124 0.36319032]
#  [0.35849801 0.27872471 0.36277728]
#  [0.35611688 0.28401559 0.35986753]
#  [0.35724624 0.27999861 0.36275515]
#  [0.36157324 0.26767368 0.37075308]
#  [0.344366   0.28579649 0.36983751]
#  [0.35447281 0.28325229 0.3622749 ]
#  [0.34167641 0.29099303 0.36733056]
#  [0.34771382 0.28782284 0.36446334]
#  [0.36119788 0.2677732  0.37102892]
#  [0.31986491 0.31614031 0.36399478]
#  [0.35139192 0.28302722 0.36558086]
#  [0.31171044 0.42676701 0.26152254]
#  [0.33845683 0.35818356 0.30335961]
#  [0.34631174 0.34725659 0.30643166]
#  [0.34096335 0.34992632 0.30911033]
#  [0.32982653 0.38604001 0.28413346]
#  [0.33395649 0.37384594 0.29219757]
#  [0.32990678 0.36184602 0.3082472 ]
#  [0.34423063 0.34349061 0.31227876]
#  [0.34193827 0.35286846 0.30519327]
#  [0.33458579 0.37721955 0.28819467]
#  [0.35335964 0.31555823 0.33108213]
#  [0.35025157 0.33428245 0.31546598]
#  [0.35125558 0.33462028 0.31412414]
#  [0.33561647 0.37024065 0.29414288]
#  [0.32477117 0.4007308  0.27449803]
#  [0.33928699 0.36119734 0.29951567]
#  [0.3499715  0.32718919 0.32283931]
#  [0.33839559 0.35925449 0.30234992]
#  [0.31548918 0.41778643 0.26672438]
#  [0.35573235 0.31386883 0.33039883]
#  [0.34310654 0.35707418 0.29981929]
#  [0.3341712  0.36555993 0.30026887]
#  [0.33284621 0.37422585 0.29292793]
#  [0.36061514 0.30376667 0.33561819]
#  [0.3423984  0.3500625  0.3075391 ]
#  [0.35438252 0.31613394 0.32948354]
#  [0.35913425 0.30283769 0.33802807]
#  [0.35174553 0.31406771 0.33418676]
#  [0.33527449 0.37343334 0.29129216]
#  [0.36312004 0.29082161 0.34605835]
#  [0.35044155 0.33318867 0.31636978]
#  [0.35777677 0.30585737 0.33636586]
#  [0.33250023 0.38225591 0.28524386]
#  [0.360725   0.29212454 0.34715046]
#  [0.34377709 0.33379056 0.32243235]
#  [0.35001871 0.34421853 0.30576276]
#  [0.32384363 0.3957249  0.28043147]
#  [0.34689119 0.33182708 0.32128172]
#  [0.35007338 0.31527195 0.33465466]
#  [0.35692636 0.31871076 0.32436288]
#  [0.33730801 0.37389055 0.28880144]
#  [0.35999769 0.31499326 0.32500905]
#  [0.33845683 0.35818356 0.30335961]
#  [0.33351528 0.37896849 0.28751623]
#  [0.33162882 0.38609501 0.28227617]
#  [0.3522839  0.33640383 0.31131227]
#  [0.35607706 0.32270989 0.32121306]
#  [0.35347832 0.32325729 0.32326439]
#  [0.32765282 0.38126482 0.29108236]
#  [0.34201536 0.33904422 0.31894042]]

# %% [markdown]
# **d)** Compute the accuracy of your model using the accuracy function defined above. Recreate your model a couple times and see how the accuracy changes.

# %%
print(accuracy(predictions, targets))

# the prediction score is varies from 0.0 to 0.63, 
#which is very unstable because our error fully depends on initial weights and biases that we set randomly
# Out:
# 0.0

# %% [markdown]
# # Exercise 7 - Training on real data (Optional)
#
# To be able to actually do anything useful with your neural network, you need to train it. For this, we need a cost function and a way to take the gradient of the cost function wrt. the network parameters. The following exercises guide you through taking the gradient using autograd, and updating the network parameters using the gradient. Feel free to implement gradient methods like ADAM if you finish everything.

# %% [markdown]
# Since we are doing a classification task with multiple output classes, we use the cross-entropy loss function, which can evaluate performance on classification tasks. It sees if your prediction is "most certain" on the correct target.

# %%
def cross_entropy(predict, target):
    return np.sum(-target * np.log(predict))


def cost(input, layers, activation_funcs, target):
    predict = feed_forward_batch(input, layers, activation_funcs)
    return cross_entropy(predict, target)

# %% [markdown]
# To improve our network on whatever prediction task we have given it, we need to use a sensible cost function, take the gradient of that cost function with respect to our network parameters, the weights and biases, and then update the weights and biases using these gradients. To clarify, we need to find and use these
#
# $$
# \frac{\partial C}{\partial W}, \frac{\partial C}{\partial b}
# $$

# %% [markdown]
# Now we need to compute these gradients. This is pretty hard to do for a neural network, we will use most of next week to do this, but we can also use autograd to just do it for us, which is what we always do in practice. With the code cell below, we create a function which takes all of these gradients for us.

# %%
from autograd import grad

gradient_func = grad(
    cost, 1
); # Taking the gradient wrt. the second input to the cost function, i.e. the layers

gradient = gradient_func(inputs, layers, activation_funcs, targets)
# Out:
# Autograd ArrayBox with value [[2.19828669e-03 6.47176008e-02 9.99938127e-01 ... 9.05455521e-01
#   9.99804527e-01 2.19790404e-03]
#  [3.30909697e-03 1.33952954e-01 9.99898094e-01 ... 8.93601083e-01
#   9.99619812e-01 3.13118547e-03]
#  [3.28505824e-03 8.22857450e-02 9.99862693e-01 ... 8.96603021e-01
#   9.99594474e-01 3.54596518e-03]
#  ...
#  [2.26897294e-03 9.64438357e-01 9.99999927e-01 ... 6.26331781e-01
#   9.97212225e-01 7.61556253e-05]
#  [2.33562182e-03 9.40080906e-01 9.99999935e-01 ... 6.00218612e-01
#   9.95590779e-01 6.62332128e-05]
#  [2.88799119e-03 9.47471798e-01 9.99999794e-01 ... 5.92448917e-01
#   9.93712887e-01 1.41540250e-04]]
# Autograd ArrayBox with value [[0.15065147 0.58335691 0.26599162]
#  [0.16565093 0.55491654 0.27943254]
#  [0.15410065 0.57662024 0.2692791 ]
#  [0.16027932 0.56385338 0.2758673 ]
#  [0.14800008 0.58829558 0.26370434]
#  [0.14807139 0.58783808 0.26409053]
#  [0.14998447 0.58380532 0.26621021]
#  [0.15388334 0.57652045 0.26959621]
#  [0.16408723 0.55722603 0.27868674]
#  [0.16304239 0.55919872 0.27775889]
#  [0.14931931 0.58606744 0.26461325]
#  [0.15383311 0.57572456 0.27044233]
#  [0.16380789 0.55820817 0.27798394]
#  [0.15312481 0.57944192 0.26743327]
#  [0.1441822  0.59798779 0.25783001]
#  [0.14196946 0.60141506 0.25661548]
#  [0.14489733 0.59569312 0.25940955]
#  [0.15098755 0.58277834 0.26623411]
#  [0.15169875 0.58136863 0.26693262]
#  [0.14624047 0.59154446 0.26221507]
#  [0.16133707 0.5623321  0.27633082]
#  [0.14820705 0.58780411 0.26398884]
#  [0.14340887 0.59840747 0.25818366]
#  [0.16400028 0.55711231 0.27888741]
#  [0.15926106 0.5637138  0.27702514]
#  [0.17288264 0.54087674 0.28624062]
#  [0.15643262 0.57136885 0.27219853]
#  [0.1526634  0.57923307 0.26810353]
#  [0.15389323 0.57734987 0.2687569 ]
#  [0.15959615 0.56469708 0.27570676]
#  [0.16496478 0.55492016 0.28011507]
#  [0.15824377 0.56928828 0.27246794]
#  [0.14264035 0.59876086 0.25859879]
#  [0.14237751 0.60036335 0.25725914]
#  [0.16365557 0.55805482 0.27828961]
#  [0.15490498 0.5759894  0.26910562]
#  [0.15197539 0.58197942 0.26604519]
#  [0.14721352 0.58963847 0.26314802]
#  [0.1578457  0.5693107  0.2728436 ]
#  [0.15468651 0.57518596 0.27012752]
#  [0.14919307 0.5864842  0.26432273]
#  [0.20409039 0.48810871 0.3078009 ]
#  [0.15178591 0.58068859 0.26752551]
#  [0.15421323 0.5758782  0.26990857]
#  [0.15053437 0.5813394  0.26812624]
#  [0.16506618 0.55584638 0.27908744]
#  [0.14682618 0.58984509 0.26332873]
#  [0.15489223 0.57448615 0.27062162]
#  [0.14875153 0.58696459 0.26428388]
#  [0.15521883 0.57447751 0.27030366]
#  [0.3695503  0.25542293 0.37502676]
#  [0.35496549 0.27847378 0.36656073]
#  [0.370977   0.26012823 0.36889476]
#  [0.36457794 0.27390796 0.3615141 ]
#  [0.37083172 0.26418972 0.36497856]
#  [0.35439272 0.28646116 0.35914612]
#  [0.35003289 0.29138639 0.35858072]
#  [0.33423486 0.29809717 0.36766797]
#  [0.37082479 0.25583835 0.37333685]
#  [0.33921757 0.30600813 0.35477431]
#  [0.36258613 0.26765027 0.3697636 ]
#  [0.34769268 0.29105215 0.36125517]
#  [0.37675746 0.24648509 0.37675746]
#  [0.36029247 0.27972468 0.35998284]
#  [0.3273819  0.30814871 0.36446939]
#  [0.36451866 0.26206222 0.37341912]
#  [0.34240948 0.30914433 0.3484462 ]
#  [0.35806754 0.26662437 0.37530808]
#  [0.37277624 0.27288529 0.35433847]
#  [0.36013176 0.26817077 0.37169747]
#  [0.34093609 0.32531319 0.33375073]
#  [0.35928262 0.26923263 0.37148474]
#  [0.36615593 0.28475875 0.34908532]
#  [0.36379957 0.26881457 0.36738586]
#  [0.36532251 0.2614282  0.37324929]
#  [0.36661323 0.26093073 0.37245603]
#  [0.37531267 0.25471818 0.36996915]
#  [0.36686    0.27935771 0.35378229]
#  [0.35752529 0.28458501 0.3578897 ]
#  [0.34781886 0.27837611 0.37380504]
#  [0.36099028 0.26787449 0.37113523]
#  [0.35948181 0.26649691 0.37402127]
#  [0.3554244  0.27340539 0.37117021]
#  [0.35168071 0.31848186 0.32983742]
#  [0.33582875 0.32167432 0.34249693]
#  [0.33164678 0.31361335 0.35473987]
#  [0.36716095 0.26425047 0.36858858]
#  [0.37692583 0.25516456 0.36790961]
#  [0.33654844 0.30026124 0.36319032]
#  [0.35849801 0.27872471 0.36277728]
#  [0.35611688 0.28401559 0.35986753]
#  [0.35724624 0.27999861 0.36275515]
#  [0.36157324 0.26767368 0.37075308]
#  [0.344366   0.28579649 0.36983751]
#  [0.35447281 0.28325229 0.3622749 ]
#  [0.34167641 0.29099303 0.36733056]
#  [0.34771382 0.28782284 0.36446334]
#  [0.36119788 0.2677732  0.37102892]
#  [0.31986491 0.31614031 0.36399478]
#  [0.35139192 0.28302722 0.36558086]
#  [0.31171044 0.42676701 0.26152254]
#  [0.33845683 0.35818356 0.30335961]
#  [0.34631174 0.34725659 0.30643166]
#  [0.34096335 0.34992632 0.30911033]
#  [0.32982653 0.38604001 0.28413346]
#  [0.33395649 0.37384594 0.29219757]
#  [0.32990678 0.36184602 0.3082472 ]
#  [0.34423063 0.34349061 0.31227876]
#  [0.34193827 0.35286846 0.30519327]
#  [0.33458579 0.37721955 0.28819467]
#  [0.35335964 0.31555823 0.33108213]
#  [0.35025157 0.33428245 0.31546598]
#  [0.35125558 0.33462028 0.31412414]
#  [0.33561647 0.37024065 0.29414288]
#  [0.32477117 0.4007308  0.27449803]
#  [0.33928699 0.36119734 0.29951567]
#  [0.3499715  0.32718919 0.32283931]
#  [0.33839559 0.35925449 0.30234992]
#  [0.31548918 0.41778643 0.26672438]
#  [0.35573235 0.31386883 0.33039883]
#  [0.34310654 0.35707418 0.29981929]
#  [0.3341712  0.36555993 0.30026887]
#  [0.33284621 0.37422585 0.29292793]
#  [0.36061514 0.30376667 0.33561819]
#  [0.3423984  0.3500625  0.3075391 ]
#  [0.35438252 0.31613394 0.32948354]
#  [0.35913425 0.30283769 0.33802807]
#  [0.35174553 0.31406771 0.33418676]
#  [0.33527449 0.37343334 0.29129216]
#  [0.36312004 0.29082161 0.34605835]
#  [0.35044155 0.33318867 0.31636978]
#  [0.35777677 0.30585737 0.33636586]
#  [0.33250023 0.38225591 0.28524386]
#  [0.360725   0.29212454 0.34715046]
#  [0.34377709 0.33379056 0.32243235]
#  [0.35001871 0.34421853 0.30576276]
#  [0.32384363 0.3957249  0.28043147]
#  [0.34689119 0.33182708 0.32128172]
#  [0.35007338 0.31527195 0.33465466]
#  [0.35692636 0.31871076 0.32436288]
#  [0.33730801 0.37389055 0.28880144]
#  [0.35999769 0.31499326 0.32500905]
#  [0.33845683 0.35818356 0.30335961]
#  [0.33351528 0.37896849 0.28751623]
#  [0.33162882 0.38609501 0.28227617]
#  [0.3522839  0.33640383 0.31131227]
#  [0.35607706 0.32270989 0.32121306]
#  [0.35347832 0.32325729 0.32326439]
#  [0.32765282 0.38126482 0.29108236]
#  [0.34201536 0.33904422 0.31894042]]

# %% [markdown]
# **a)** What shape should the gradient of the cost function wrt. weights and biases be?

# %%
shapes = []
for item in gradient:
    for array in item:
        if isinstance(array, np.ndarray):
            shapes.append(array.shape)  # Append the shape tuple

# Print the shapes
print(shapes)
# Out:
# [(4, 8), (8,), (8, 3), (3,)]

# %% [markdown]
# The shape of the weight function for the hidden layer is [4, 8], for the output is [8, 3] because we get 4 parameters for each input variable and we have 8 nodes in the hidden layer and 3 nodes for the output layer.
#
# The shape of the bias function for the hidden layer is a vector of length 8, and for the output layer it will be 3.

# %% [markdown]
# **b)** Use the `gradient_func` function to take the gradient of the cross entropy wrt. the weights and biases of the network. Check the shapes of what's inside. What does the `grad` func from autograd actually do?

# %% [markdown]
# - Grad function is used to compute the sum of gradients of a given set of outputs with respect to a given set of inputs.

# %%
layers_grad = gradient_func(
    inputs, layers, activation_funcs, targets
)  # Don't change this
# Out:
# Autograd ArrayBox with value [[2.19828669e-03 6.47176008e-02 9.99938127e-01 ... 9.05455521e-01
#   9.99804527e-01 2.19790404e-03]
#  [3.30909697e-03 1.33952954e-01 9.99898094e-01 ... 8.93601083e-01
#   9.99619812e-01 3.13118547e-03]
#  [3.28505824e-03 8.22857450e-02 9.99862693e-01 ... 8.96603021e-01
#   9.99594474e-01 3.54596518e-03]
#  ...
#  [2.26897294e-03 9.64438357e-01 9.99999927e-01 ... 6.26331781e-01
#   9.97212225e-01 7.61556253e-05]
#  [2.33562182e-03 9.40080906e-01 9.99999935e-01 ... 6.00218612e-01
#   9.95590779e-01 6.62332128e-05]
#  [2.88799119e-03 9.47471798e-01 9.99999794e-01 ... 5.92448917e-01
#   9.93712887e-01 1.41540250e-04]]
# Autograd ArrayBox with value [[0.15065147 0.58335691 0.26599162]
#  [0.16565093 0.55491654 0.27943254]
#  [0.15410065 0.57662024 0.2692791 ]
#  [0.16027932 0.56385338 0.2758673 ]
#  [0.14800008 0.58829558 0.26370434]
#  [0.14807139 0.58783808 0.26409053]
#  [0.14998447 0.58380532 0.26621021]
#  [0.15388334 0.57652045 0.26959621]
#  [0.16408723 0.55722603 0.27868674]
#  [0.16304239 0.55919872 0.27775889]
#  [0.14931931 0.58606744 0.26461325]
#  [0.15383311 0.57572456 0.27044233]
#  [0.16380789 0.55820817 0.27798394]
#  [0.15312481 0.57944192 0.26743327]
#  [0.1441822  0.59798779 0.25783001]
#  [0.14196946 0.60141506 0.25661548]
#  [0.14489733 0.59569312 0.25940955]
#  [0.15098755 0.58277834 0.26623411]
#  [0.15169875 0.58136863 0.26693262]
#  [0.14624047 0.59154446 0.26221507]
#  [0.16133707 0.5623321  0.27633082]
#  [0.14820705 0.58780411 0.26398884]
#  [0.14340887 0.59840747 0.25818366]
#  [0.16400028 0.55711231 0.27888741]
#  [0.15926106 0.5637138  0.27702514]
#  [0.17288264 0.54087674 0.28624062]
#  [0.15643262 0.57136885 0.27219853]
#  [0.1526634  0.57923307 0.26810353]
#  [0.15389323 0.57734987 0.2687569 ]
#  [0.15959615 0.56469708 0.27570676]
#  [0.16496478 0.55492016 0.28011507]
#  [0.15824377 0.56928828 0.27246794]
#  [0.14264035 0.59876086 0.25859879]
#  [0.14237751 0.60036335 0.25725914]
#  [0.16365557 0.55805482 0.27828961]
#  [0.15490498 0.5759894  0.26910562]
#  [0.15197539 0.58197942 0.26604519]
#  [0.14721352 0.58963847 0.26314802]
#  [0.1578457  0.5693107  0.2728436 ]
#  [0.15468651 0.57518596 0.27012752]
#  [0.14919307 0.5864842  0.26432273]
#  [0.20409039 0.48810871 0.3078009 ]
#  [0.15178591 0.58068859 0.26752551]
#  [0.15421323 0.5758782  0.26990857]
#  [0.15053437 0.5813394  0.26812624]
#  [0.16506618 0.55584638 0.27908744]
#  [0.14682618 0.58984509 0.26332873]
#  [0.15489223 0.57448615 0.27062162]
#  [0.14875153 0.58696459 0.26428388]
#  [0.15521883 0.57447751 0.27030366]
#  [0.3695503  0.25542293 0.37502676]
#  [0.35496549 0.27847378 0.36656073]
#  [0.370977   0.26012823 0.36889476]
#  [0.36457794 0.27390796 0.3615141 ]
#  [0.37083172 0.26418972 0.36497856]
#  [0.35439272 0.28646116 0.35914612]
#  [0.35003289 0.29138639 0.35858072]
#  [0.33423486 0.29809717 0.36766797]
#  [0.37082479 0.25583835 0.37333685]
#  [0.33921757 0.30600813 0.35477431]
#  [0.36258613 0.26765027 0.3697636 ]
#  [0.34769268 0.29105215 0.36125517]
#  [0.37675746 0.24648509 0.37675746]
#  [0.36029247 0.27972468 0.35998284]
#  [0.3273819  0.30814871 0.36446939]
#  [0.36451866 0.26206222 0.37341912]
#  [0.34240948 0.30914433 0.3484462 ]
#  [0.35806754 0.26662437 0.37530808]
#  [0.37277624 0.27288529 0.35433847]
#  [0.36013176 0.26817077 0.37169747]
#  [0.34093609 0.32531319 0.33375073]
#  [0.35928262 0.26923263 0.37148474]
#  [0.36615593 0.28475875 0.34908532]
#  [0.36379957 0.26881457 0.36738586]
#  [0.36532251 0.2614282  0.37324929]
#  [0.36661323 0.26093073 0.37245603]
#  [0.37531267 0.25471818 0.36996915]
#  [0.36686    0.27935771 0.35378229]
#  [0.35752529 0.28458501 0.3578897 ]
#  [0.34781886 0.27837611 0.37380504]
#  [0.36099028 0.26787449 0.37113523]
#  [0.35948181 0.26649691 0.37402127]
#  [0.3554244  0.27340539 0.37117021]
#  [0.35168071 0.31848186 0.32983742]
#  [0.33582875 0.32167432 0.34249693]
#  [0.33164678 0.31361335 0.35473987]
#  [0.36716095 0.26425047 0.36858858]
#  [0.37692583 0.25516456 0.36790961]
#  [0.33654844 0.30026124 0.36319032]
#  [0.35849801 0.27872471 0.36277728]
#  [0.35611688 0.28401559 0.35986753]
#  [0.35724624 0.27999861 0.36275515]
#  [0.36157324 0.26767368 0.37075308]
#  [0.344366   0.28579649 0.36983751]
#  [0.35447281 0.28325229 0.3622749 ]
#  [0.34167641 0.29099303 0.36733056]
#  [0.34771382 0.28782284 0.36446334]
#  [0.36119788 0.2677732  0.37102892]
#  [0.31986491 0.31614031 0.36399478]
#  [0.35139192 0.28302722 0.36558086]
#  [0.31171044 0.42676701 0.26152254]
#  [0.33845683 0.35818356 0.30335961]
#  [0.34631174 0.34725659 0.30643166]
#  [0.34096335 0.34992632 0.30911033]
#  [0.32982653 0.38604001 0.28413346]
#  [0.33395649 0.37384594 0.29219757]
#  [0.32990678 0.36184602 0.3082472 ]
#  [0.34423063 0.34349061 0.31227876]
#  [0.34193827 0.35286846 0.30519327]
#  [0.33458579 0.37721955 0.28819467]
#  [0.35335964 0.31555823 0.33108213]
#  [0.35025157 0.33428245 0.31546598]
#  [0.35125558 0.33462028 0.31412414]
#  [0.33561647 0.37024065 0.29414288]
#  [0.32477117 0.4007308  0.27449803]
#  [0.33928699 0.36119734 0.29951567]
#  [0.3499715  0.32718919 0.32283931]
#  [0.33839559 0.35925449 0.30234992]
#  [0.31548918 0.41778643 0.26672438]
#  [0.35573235 0.31386883 0.33039883]
#  [0.34310654 0.35707418 0.29981929]
#  [0.3341712  0.36555993 0.30026887]
#  [0.33284621 0.37422585 0.29292793]
#  [0.36061514 0.30376667 0.33561819]
#  [0.3423984  0.3500625  0.3075391 ]
#  [0.35438252 0.31613394 0.32948354]
#  [0.35913425 0.30283769 0.33802807]
#  [0.35174553 0.31406771 0.33418676]
#  [0.33527449 0.37343334 0.29129216]
#  [0.36312004 0.29082161 0.34605835]
#  [0.35044155 0.33318867 0.31636978]
#  [0.35777677 0.30585737 0.33636586]
#  [0.33250023 0.38225591 0.28524386]
#  [0.360725   0.29212454 0.34715046]
#  [0.34377709 0.33379056 0.32243235]
#  [0.35001871 0.34421853 0.30576276]
#  [0.32384363 0.3957249  0.28043147]
#  [0.34689119 0.33182708 0.32128172]
#  [0.35007338 0.31527195 0.33465466]
#  [0.35692636 0.31871076 0.32436288]
#  [0.33730801 0.37389055 0.28880144]
#  [0.35999769 0.31499326 0.32500905]
#  [0.33845683 0.35818356 0.30335961]
#  [0.33351528 0.37896849 0.28751623]
#  [0.33162882 0.38609501 0.28227617]
#  [0.3522839  0.33640383 0.31131227]
#  [0.35607706 0.32270989 0.32121306]
#  [0.35347832 0.32325729 0.32326439]
#  [0.32765282 0.38126482 0.29108236]
#  [0.34201536 0.33904422 0.31894042]]

# %% [markdown]
# **c)** Finish the `train_network` function.

# %%
def train_network(_inputs, _layers, activation_funcs, targets, learning_rate=0.001, epochs=30):
    predictions = []
    prediction = _inputs
    for i in range(epochs):
        layers_grad = gradient_func(_inputs, _layers, activation_funcs, targets)
        for (W, b), (W_g, b_g) in zip(_layers, layers_grad):
            W -= W_g * learning_rate
            b -= b_g * learning_rate
        prediction = feed_forward_batch(_inputs,_layers,activation_funcs)
        predictions.append(prediction)

        #print(accuracy(prediction, targets))

    return predictions

# %% [markdown]
# **e)** What do we call the gradient method used above?

# %% [markdown]
# Gradient Descent

# %% [markdown]
# **d)** Train your network and see how the accuracy changes! Make a plot if you want.

# %%
lern_rate = 0.001
n_iter = 100
predictions_final = train_network(inputs, layers, activation_funcs, targets, learning_rate=0.001, epochs=n_iter)

accuracy_values = []
for pred in predictions_final:
    acc = accuracy(pred, targets)
    accuracy_values.append(acc)

# Print the collected accuracy values
#print(accuracy_values)
# Out:
# Autograd ArrayBox with value [[2.19828669e-03 6.47176008e-02 9.99938127e-01 ... 9.05455521e-01
#   9.99804527e-01 2.19790404e-03]
#  [3.30909697e-03 1.33952954e-01 9.99898094e-01 ... 8.93601083e-01
#   9.99619812e-01 3.13118547e-03]
#  [3.28505824e-03 8.22857450e-02 9.99862693e-01 ... 8.96603021e-01
#   9.99594474e-01 3.54596518e-03]
#  ...
#  [2.26897294e-03 9.64438357e-01 9.99999927e-01 ... 6.26331781e-01
#   9.97212225e-01 7.61556253e-05]
#  [2.33562182e-03 9.40080906e-01 9.99999935e-01 ... 6.00218612e-01
#   9.95590779e-01 6.62332128e-05]
#  [2.88799119e-03 9.47471798e-01 9.99999794e-01 ... 5.92448917e-01
#   9.93712887e-01 1.41540250e-04]]
# Autograd ArrayBox with value [[0.15065147 0.58335691 0.26599162]
#  [0.16565093 0.55491654 0.27943254]
#  [0.15410065 0.57662024 0.2692791 ]
#  [0.16027932 0.56385338 0.2758673 ]
#  [0.14800008 0.58829558 0.26370434]
#  [0.14807139 0.58783808 0.26409053]
#  [0.14998447 0.58380532 0.26621021]
#  [0.15388334 0.57652045 0.26959621]
#  [0.16408723 0.55722603 0.27868674]
#  [0.16304239 0.55919872 0.27775889]
#  [0.14931931 0.58606744 0.26461325]
#  [0.15383311 0.57572456 0.27044233]
#  [0.16380789 0.55820817 0.27798394]
#  [0.15312481 0.57944192 0.26743327]
#  [0.1441822  0.59798779 0.25783001]
#  [0.14196946 0.60141506 0.25661548]
#  [0.14489733 0.59569312 0.25940955]
#  [0.15098755 0.58277834 0.26623411]
#  [0.15169875 0.58136863 0.26693262]
#  [0.14624047 0.59154446 0.26221507]
#  [0.16133707 0.5623321  0.27633082]
#  [0.14820705 0.58780411 0.26398884]
#  [0.14340887 0.59840747 0.25818366]
#  [0.16400028 0.55711231 0.27888741]
#  [0.15926106 0.5637138  0.27702514]
#  [0.17288264 0.54087674 0.28624062]
#  [0.15643262 0.57136885 0.27219853]
#  [0.1526634  0.57923307 0.26810353]
#  [0.15389323 0.57734987 0.2687569 ]
#  [0.15959615 0.56469708 0.27570676]
#  [0.16496478 0.55492016 0.28011507]
#  [0.15824377 0.56928828 0.27246794]
#  [0.14264035 0.59876086 0.25859879]
#  [0.14237751 0.60036335 0.25725914]
#  [0.16365557 0.55805482 0.27828961]
#  [0.15490498 0.5759894  0.26910562]
#  [0.15197539 0.58197942 0.26604519]
#  [0.14721352 0.58963847 0.26314802]
#  [0.1578457  0.5693107  0.2728436 ]
#  [0.15468651 0.57518596 0.27012752]
#  [0.14919307 0.5864842  0.26432273]
#  [0.20409039 0.48810871 0.3078009 ]
#  [0.15178591 0.58068859 0.26752551]
#  [0.15421323 0.5758782  0.26990857]
#  [0.15053437 0.5813394  0.26812624]
#  [0.16506618 0.55584638 0.27908744]
#  [0.14682618 0.58984509 0.26332873]
#  [0.15489223 0.57448615 0.27062162]
#  [0.14875153 0.58696459 0.26428388]
#  [0.15521883 0.57447751 0.27030366]
#  [0.3695503  0.25542293 0.37502676]
#  [0.35496549 0.27847378 0.36656073]
#  [0.370977   0.26012823 0.36889476]
#  [0.36457794 0.27390796 0.3615141 ]
#  [0.37083172 0.26418972 0.36497856]
#  [0.35439272 0.28646116 0.35914612]
#  [0.35003289 0.29138639 0.35858072]
#  [0.33423486 0.29809717 0.36766797]
#  [0.37082479 0.25583835 0.37333685]
#  [0.33921757 0.30600813 0.35477431]
#  [0.36258613 0.26765027 0.3697636 ]
#  [0.34769268 0.29105215 0.36125517]
#  [0.37675746 0.24648509 0.37675746]
#  [0.36029247 0.27972468 0.35998284]
#  [0.3273819  0.30814871 0.36446939]
#  [0.36451866 0.26206222 0.37341912]
#  [0.34240948 0.30914433 0.3484462 ]
#  [0.35806754 0.26662437 0.37530808]
#  [0.37277624 0.27288529 0.35433847]
#  [0.36013176 0.26817077 0.37169747]
#  [0.34093609 0.32531319 0.33375073]
#  [0.35928262 0.26923263 0.37148474]
#  [0.36615593 0.28475875 0.34908532]
#  [0.36379957 0.26881457 0.36738586]
#  [0.36532251 0.2614282  0.37324929]
#  [0.36661323 0.26093073 0.37245603]
#  [0.37531267 0.25471818 0.36996915]
#  [0.36686    0.27935771 0.35378229]
#  [0.35752529 0.28458501 0.3578897 ]
#  [0.34781886 0.27837611 0.37380504]
#  [0.36099028 0.26787449 0.37113523]
#  [0.35948181 0.26649691 0.37402127]
#  [0.3554244  0.27340539 0.37117021]
#  [0.35168071 0.31848186 0.32983742]
#  [0.33582875 0.32167432 0.34249693]
#  [0.33164678 0.31361335 0.35473987]
#  [0.36716095 0.26425047 0.36858858]
#  [0.37692583 0.25516456 0.36790961]
#  [0.33654844 0.30026124 0.36319032]
#  [0.35849801 0.27872471 0.36277728]
#  [0.35611688 0.28401559 0.35986753]
#  [0.35724624 0.27999861 0.36275515]
#  [0.36157324 0.26767368 0.37075308]
#  [0.344366   0.28579649 0.36983751]
#  [0.35447281 0.28325229 0.3622749 ]
#  [0.34167641 0.29099303 0.36733056]
#  [0.34771382 0.28782284 0.36446334]
#  [0.36119788 0.2677732  0.37102892]
#  [0.31986491 0.31614031 0.36399478]
#  [0.35139192 0.28302722 0.36558086]
#  [0.31171044 0.42676701 0.26152254]
#  [0.33845683 0.35818356 0.30335961]
#  [0.34631174 0.34725659 0.30643166]
#  [0.34096335 0.34992632 0.30911033]
#  [0.32982653 0.38604001 0.28413346]
#  [0.33395649 0.37384594 0.29219757]
#  [0.32990678 0.36184602 0.3082472 ]
#  [0.34423063 0.34349061 0.31227876]
#  [0.34193827 0.35286846 0.30519327]
#  [0.33458579 0.37721955 0.28819467]
#  [0.35335964 0.31555823 0.33108213]
#  [0.35025157 0.33428245 0.31546598]
#  [0.35125558 0.33462028 0.31412414]
#  [0.33561647 0.37024065 0.29414288]
#  [0.32477117 0.4007308  0.27449803]
#  [0.33928699 0.36119734 0.29951567]
#  [0.3499715  0.32718919 0.32283931]
#  [0.33839559 0.35925449 0.30234992]
#  [0.31548918 0.41778643 0.26672438]
#  [0.35573235 0.31386883 0.33039883]
#  [0.34310654 0.35707418 0.29981929]
#  [0.3341712  0.36555993 0.30026887]
#  [0.33284621 0.37422585 0.29292793]
#  [0.36061514 0.30376667 0.33561819]
#  [0.3423984  0.3500625  0.3075391 ]
#  [0.35438252 0.31613394 0.32948354]
#  [0.35913425 0.30283769 0.33802807]
#  [0.35174553 0.31406771 0.33418676]
#  [0.33527449 0.37343334 0.29129216]
#  [0.36312004 0.29082161 0.34605835]
#  [0.35044155 0.33318867 0.31636978]
#  [0.35777677 0.30585737 0.33636586]
#  [0.33250023 0.38225591 0.28524386]
#  [0.360725   0.29212454 0.34715046]
#  [0.34377709 0.33379056 0.32243235]
#  [0.35001871 0.34421853 0.30576276]
#  [0.32384363 0.3957249  0.28043147]
#  [0.34689119 0.33182708 0.32128172]
#  [0.35007338 0.31527195 0.33465466]
#  [0.35692636 0.31871076 0.32436288]
#  [0.33730801 0.37389055 0.28880144]
#  [0.35999769 0.31499326 0.32500905]
#  [0.33845683 0.35818356 0.30335961]
#  [0.33351528 0.37896849 0.28751623]
#  [0.33162882 0.38609501 0.28227617]
#  [0.3522839  0.33640383 0.31131227]
#  [0.35607706 0.32270989 0.32121306]
#  [0.35347832 0.32325729 0.32326439]
#  [0.32765282 0.38126482 0.29108236]
#  [0.34201536 0.33904422 0.31894042]]
# [[2.20223858e-03 6.06321705e-02 9.99938150e-01 ... 8.95855169e-01
#   9.99803579e-01 2.19886463e-03]
#  [3.31486455e-03 1.26243865e-01 9.99898130e-01 ... 8.83471756e-01
#   9.99618065e-01 3.13246277e-03]
#  [3.29051714e-03 7.75478384e-02 9.99862741e-01 ... 8.87038805e-01
#   9.99592660e-01 3.54739218e-03]
#  ...
#  [2.27683652e-03 9.58627546e-01 9.99999927e-01 ... 5.81265853e-01
#   9.97188982e-01 7.61974654e-05]
#  [2.34373882e-03 9.30442432e-01 9.99999935e-01 ... 5.53626159e-01
#   9.95553435e-01 6.62696201e-05]
#  [2.89741259e-03 9.39544633e-01 9.99999794e-01 ... 5.48869769e-01
#   9.93663519e-01 1.41613109e-04]]
# [[0.15616456 0.58581279 0.25802265]
#  [0.17034596 0.55903765 0.27061639]
#  [0.15946587 0.57938695 0.26114718]
#  [0.16517792 0.56738575 0.26743633]
#  [0.15365842 0.590408   0.25593358]
#  [0.15359905 0.59008889 0.25631206]
#  [0.15549827 0.58613389 0.25836784]
#  [0.1591457  0.5794029  0.26145139]
#  [0.16887232 0.56102704 0.27010064]
#  [0.16780229 0.56309199 0.26910571]
#  [0.15487556 0.58841634 0.2567081 ]
#  [0.15902091 0.57861498 0.26236411]
#  [0.16860975 0.56208378 0.26930647]
#  [0.15864867 0.58192599 0.25942534]
#  [0.15021933 0.59958165 0.25019902]
#  [0.14803818 0.60273329 0.24922854]
#  [0.15082201 0.59740088 0.25177711]
#  [0.1564796  0.58528551 0.25823489]
#  [0.15700804 0.58415607 0.25883589]
#  [0.15196145 0.59346557 0.25457298]
#  [0.16602679 0.56631512 0.26765809]
#  [0.1538079  0.58999261 0.25619949]
#  [0.14946357 0.59984859 0.25068784]
#  [0.1685098  0.56137708 0.27011313]
#  [0.16389884 0.56742086 0.2686803 ]
#  [0.17701441 0.54592725 0.27705834]
#  [0.16147178 0.57463344 0.26389477]
#  [0.15800635 0.58199399 0.25999967]
#  [0.15922602 0.5802199  0.26055407]
#  [0.16445533 0.56824009 0.26730457]
#  [0.16953098 0.55908012 0.2713889 ]
#  [0.16325462 0.57280593 0.26393945]
#  [0.14859419 0.600183   0.25122282]
#  [0.14842736 0.60173124 0.24984141]
#  [0.16837459 0.56203541 0.26959   ]
#  [0.16029858 0.57885259 0.26084883]
#  [0.15748572 0.58461257 0.25790171]
#  [0.15290854 0.59163709 0.25545437]
#  [0.16301307 0.57241968 0.26456725]
#  [0.15990711 0.57818274 0.26191015]
#  [0.15483531 0.58872234 0.25644235]
#  [0.20720118 0.49495809 0.29784073]
#  [0.15725364 0.58314969 0.25959667]
#  [0.15937739 0.57888304 0.26173958]
#  [0.1557457  0.58397838 0.26027592]
#  [0.16978515 0.55989688 0.27031798]
#  [0.15245746 0.59186777 0.25567477]
#  [0.16014688 0.57737098 0.26248214]
#  [0.15433542 0.58922916 0.25643542]
#  [0.1604709  0.57747263 0.26205648]
#  [0.36685387 0.25898261 0.37416352]
#  [0.35167725 0.28251974 0.36580301]
#  [0.36864718 0.26130626 0.37004657]
#  [0.36300463 0.27503105 0.36196432]
#  [0.36892564 0.26495878 0.36611558]
#  [0.35181071 0.2875474  0.36064188]
#  [0.34653373 0.29410646 0.35935981]
#  [0.33191656 0.30456552 0.36351792]
#  [0.36861208 0.25813622 0.37325171]
#  [0.33636411 0.30966738 0.3539685 ]
#  [0.36128303 0.27052654 0.36819043]
#  [0.34452936 0.29520934 0.3602613 ]
#  [0.37559901 0.24880198 0.37559901]
#  [0.35784883 0.28017347 0.3619777 ]
#  [0.32407618 0.31617783 0.35974599]
#  [0.3617399  0.26657729 0.37168281]
#  [0.33926249 0.31054906 0.35018845]
#  [0.35554176 0.27098157 0.37347667]
#  [0.3717576  0.27102173 0.35722067]
#  [0.35804012 0.27191274 0.37004713]
#  [0.33784142 0.32467895 0.33747963]
#  [0.35677162 0.27405982 0.36916856]
#  [0.36474953 0.28177522 0.35347525]
#  [0.36148597 0.26963517 0.36887887]
#  [0.36285856 0.26531413 0.37182731]
#  [0.3640918  0.26468126 0.37122694]
#  [0.37353192 0.25523818 0.3712299 ]
#  [0.36487865 0.27784924 0.35727211]
#  [0.35497428 0.2858332  0.35919252]
#  [0.34538965 0.28528239 0.36932796]
#  [0.35908791 0.27148421 0.36942788]
#  [0.35753852 0.27095246 0.37150903]
#  [0.35291767 0.27830271 0.36877962]
#  [0.35000839 0.31401924 0.33597237]
#  [0.33255414 0.32281973 0.34462613]
#  [0.32733885 0.31863573 0.35402542]
#  [0.36460402 0.26645949 0.36893649]
#  [0.37574453 0.25534601 0.36890947]
#  [0.33301089 0.30577828 0.36121083]
#  [0.35643428 0.28101009 0.36255563]
#  [0.35385592 0.28470285 0.36144122]
#  [0.35443841 0.28185394 0.36370765]
#  [0.35940556 0.27128145 0.369313  ]
#  [0.34235383 0.29156566 0.36608051]
#  [0.3519726  0.28565158 0.36237582]
#  [0.33820583 0.29625714 0.36553703]
#  [0.34463981 0.29183741 0.36352278]
#  [0.35856645 0.27152279 0.36991075]
#  [0.31755788 0.32464897 0.35779314]
#  [0.34860352 0.28696022 0.36443625]
#  [0.30859467 0.42290333 0.268502  ]
#  [0.33676693 0.3529716  0.31026147]
#  [0.34512806 0.33939645 0.31547549]
#  [0.3393402  0.3435227  0.3171371 ]
#  [0.32805199 0.37951618 0.29243183]
#  [0.33264139 0.36489981 0.3024588 ]
#  [0.32769675 0.3590188  0.31328445]
#  [0.34299211 0.33494309 0.32206481]
#  [0.34076066 0.3452992  0.31394014]
#  [0.33277784 0.36984724 0.29737492]
#  [0.35116344 0.31238589 0.33645067]
#  [0.34898839 0.3281764  0.32283521]
#  [0.34994785 0.32810278 0.32194937]
#  [0.33406743 0.36496641 0.30096617]
#  [0.32265246 0.39629084 0.2810567 ]
#  [0.33737977 0.35584349 0.30677675]
#  [0.34829996 0.32145036 0.33024968]
#  [0.33670477 0.35034454 0.31295069]
#  [0.31315288 0.41138439 0.27546274]
#  [0.35458506 0.30878413 0.33663081]
#  [0.34168141 0.34999507 0.30832353]
#  [0.33213096 0.36137153 0.30649751]
#  [0.3315443  0.36515106 0.30330464]
#  [0.35915989 0.30006801 0.3407721 ]
#  [0.34057494 0.34368227 0.31574279]
#  [0.35279023 0.30927528 0.33793449]
#  [0.35739491 0.30008864 0.34251645]
#  [0.34951864 0.31155377 0.33892759]
#  [0.33377737 0.36677435 0.29944828]
#  [0.36145404 0.2855655  0.35298046]
#  [0.34935294 0.32487451 0.32577254]
#  [0.35570299 0.29915507 0.34514194]
#  [0.33092964 0.37578097 0.29328939]
#  [0.35888256 0.28908662 0.35203082]
#  [0.34224036 0.32755341 0.33020623]
#  [0.3491529  0.33538689 0.31546021]
#  [0.32126257 0.39082186 0.28791557]
#  [0.34499417 0.32638815 0.32861768]
#  [0.34770564 0.31334303 0.33895133]
#  [0.3554635  0.31316174 0.33137476]
#  [0.33581738 0.36715706 0.29702556]
#  [0.35860144 0.31042658 0.33097198]
#  [0.33676693 0.3529716  0.31026147]
#  [0.33185114 0.37191412 0.29623474]
#  [0.32976272 0.37979648 0.2904408 ]
#  [0.35102353 0.33060563 0.31837084]
#  [0.35501203 0.31730341 0.32768456]
#  [0.35184678 0.31838613 0.32976709]
#  [0.32499924 0.37681507 0.29818569]
#  [0.33980932 0.33507352 0.32511715]]
# Autograd ArrayBox with value [[2.20223858e-03 6.06321705e-02 9.99938150e-01 ... 8.95855169e-01
#   9.99803579e-01 2.19886463e-03]
#  [3.31486455e-03 1.26243865e-01 9.99898130e-01 ... 8.83471756e-01
#   9.99618065e-01 3.13246277e-03]
#  [3.29051714e-03 7.75478384e-02 9.99862741e-01 ... 8.87038805e-01
#   9.99592660e-01 3.54739218e-03]
#  ...
#  [2.27683652e-03 9.58627546e-01 9.99999927e-01 ... 5.81265853e-01
#   9.97188982e-01 7.61974654e-05]
#  [2.34373882e-03 9.30442432e-01 9.99999935e-01 ... 5.53626159e-01
#   9.95553435e-01 6.62696201e-05]
#  [2.89741259e-03 9.39544633e-01 9.99999794e-01 ... 5.48869769e-01
#   9.93663519e-01 1.41613109e-04]]
# Autograd ArrayBox with value [[0.15616456 0.58581279 0.25802265]
#  [0.17034596 0.55903765 0.27061639]
#  [0.15946587 0.57938695 0.26114718]
#  [0.16517792 0.56738575 0.26743633]
#  [0.15365842 0.590408   0.25593358]
#  [0.15359905 0.59008889 0.25631206]
#  [0.15549827 0.58613389 0.25836784]
#  [0.1591457  0.5794029  0.26145139]
#  [0.16887232 0.56102704 0.27010064]
#  [0.16780229 0.56309199 0.26910571]
#  [0.15487556 0.58841634 0.2567081 ]
#  [0.15902091 0.57861498 0.26236411]
#  [0.16860975 0.56208378 0.26930647]
#  [0.15864867 0.58192599 0.25942534]
#  [0.15021933 0.59958165 0.25019902]
#  [0.14803818 0.60273329 0.24922854]
#  [0.15082201 0.59740088 0.25177711]
#  [0.1564796  0.58528551 0.25823489]
#  [0.15700804 0.58415607 0.25883589]
#  [0.15196145 0.59346557 0.25457298]
#  [0.16602679 0.56631512 0.26765809]
#  [0.1538079  0.58999261 0.25619949]
#  [0.14946357 0.59984859 0.25068784]
#  [0.1685098  0.56137708 0.27011313]
#  [0.16389884 0.56742086 0.2686803 ]
#  [0.17701441 0.54592725 0.27705834]
#  [0.16147178 0.57463344 0.26389477]
#  [0.15800635 0.58199399 0.25999967]
#  [0.15922602 0.5802199  0.26055407]
#  [0.16445533 0.56824009 0.26730457]
#  [0.16953098 0.55908012 0.2713889 ]
#  [0.16325462 0.57280593 0.26393945]
#  [0.14859419 0.600183   0.25122282]
#  [0.14842736 0.60173124 0.24984141]
#  [0.16837459 0.56203541 0.26959   ]
#  [0.16029858 0.57885259 0.26084883]
#  [0.15748572 0.58461257 0.25790171]
#  [0.15290854 0.59163709 0.25545437]
#  [0.16301307 0.57241968 0.26456725]
#  [0.15990711 0.57818274 0.26191015]
#  [0.15483531 0.58872234 0.25644235]
#  [0.20720118 0.49495809 0.29784073]
#  [0.15725364 0.58314969 0.25959667]
#  [0.15937739 0.57888304 0.26173958]
#  [0.1557457  0.58397838 0.26027592]
#  [0.16978515 0.55989688 0.27031798]
#  [0.15245746 0.59186777 0.25567477]
#  [0.16014688 0.57737098 0.26248214]
#  [0.15433542 0.58922916 0.25643542]
#  [0.1604709  0.57747263 0.26205648]
#  [0.36685387 0.25898261 0.37416352]
#  [0.35167725 0.28251974 0.36580301]
#  [0.36864718 0.26130626 0.37004657]
#  [0.36300463 0.27503105 0.36196432]
#  [0.36892564 0.26495878 0.36611558]
#  [0.35181071 0.2875474  0.36064188]
#  [0.34653373 0.29410646 0.35935981]
#  [0.33191656 0.30456552 0.36351792]
#  [0.36861208 0.25813622 0.37325171]
#  [0.33636411 0.30966738 0.3539685 ]
#  [0.36128303 0.27052654 0.36819043]
#  [0.34452936 0.29520934 0.3602613 ]
#  [0.37559901 0.24880198 0.37559901]
#  [0.35784883 0.28017347 0.3619777 ]
#  [0.32407618 0.31617783 0.35974599]
#  [0.3617399  0.26657729 0.37168281]
#  [0.33926249 0.31054906 0.35018845]
#  [0.35554176 0.27098157 0.37347667]
#  [0.3717576  0.27102173 0.35722067]
#  [0.35804012 0.27191274 0.37004713]
#  [0.33784142 0.32467895 0.33747963]
#  [0.35677162 0.27405982 0.36916856]
#  [0.36474953 0.28177522 0.35347525]
#  [0.36148597 0.26963517 0.36887887]
#  [0.36285856 0.26531413 0.37182731]
#  [0.3640918  0.26468126 0.37122694]
#  [0.37353192 0.25523818 0.3712299 ]
#  [0.36487865 0.27784924 0.35727211]
#  [0.35497428 0.2858332  0.35919252]
#  [0.34538965 0.28528239 0.36932796]
#  [0.35908791 0.27148421 0.36942788]
#  [0.35753852 0.27095246 0.37150903]
#  [0.35291767 0.27830271 0.36877962]
#  [0.35000839 0.31401924 0.33597237]
#  [0.33255414 0.32281973 0.34462613]
#  [0.32733885 0.31863573 0.35402542]
#  [0.36460402 0.26645949 0.36893649]
#  [0.37574453 0.25534601 0.36890947]
#  [0.33301089 0.30577828 0.36121083]
#  [0.35643428 0.28101009 0.36255563]
#  [0.35385592 0.28470285 0.36144122]
#  [0.35443841 0.28185394 0.36370765]
#  [0.35940556 0.27128145 0.369313  ]
#  [0.34235383 0.29156566 0.36608051]
#  [0.3519726  0.28565158 0.36237582]
#  [0.33820583 0.29625714 0.36553703]
#  [0.34463981 0.29183741 0.36352278]
#  [0.35856645 0.27152279 0.36991075]
#  [0.31755788 0.32464897 0.35779314]
#  [0.34860352 0.28696022 0.36443625]
#  [0.30859467 0.42290333 0.268502  ]
#  [0.33676693 0.3529716  0.31026147]
#  [0.34512806 0.33939645 0.31547549]
#  [0.3393402  0.3435227  0.3171371 ]
#  [0.32805199 0.37951618 0.29243183]
#  [0.33264139 0.36489981 0.3024588 ]
#  [0.32769675 0.3590188  0.31328445]
#  [0.34299211 0.33494309 0.32206481]
#  [0.34076066 0.3452992  0.31394014]
#  [0.33277784 0.36984724 0.29737492]
#  [0.35116344 0.31238589 0.33645067]
#  [0.34898839 0.3281764  0.32283521]
#  [0.34994785 0.32810278 0.32194937]
#  [0.33406743 0.36496641 0.30096617]
#  [0.32265246 0.39629084 0.2810567 ]
#  [0.33737977 0.35584349 0.30677675]
#  [0.34829996 0.32145036 0.33024968]
#  [0.33670477 0.35034454 0.31295069]
#  [0.31315288 0.41138439 0.27546274]
#  [0.35458506 0.30878413 0.33663081]
#  [0.34168141 0.34999507 0.30832353]
#  [0.33213096 0.36137153 0.30649751]
#  [0.3315443  0.36515106 0.30330464]
#  [0.35915989 0.30006801 0.3407721 ]
#  [0.34057494 0.34368227 0.31574279]
#  [0.35279023 0.30927528 0.33793449]
#  [0.35739491 0.30008864 0.34251645]
#  [0.34951864 0.31155377 0.33892759]
#  [0.33377737 0.36677435 0.29944828]
#  [0.36145404 0.2855655  0.35298046]
#  [0.34935294 0.32487451 0.32577254]
#  [0.35570299 0.29915507 0.34514194]
#  [0.33092964 0.37578097 0.29328939]
#  [0.35888256 0.28908662 0.35203082]
#  [0.34224036 0.32755341 0.33020623]
#  [0.3491529  0.33538689 0.31546021]
#  [0.32126257 0.39082186 0.28791557]
#  [0.34499417 0.32638815 0.32861768]
#  [0.34770564 0.31334303 0.33895133]
#  [0.3554635  0.31316174 0.33137476]
#  [0.33581738 0.36715706 0.29702556]
#  [0.35860144 0.31042658 0.33097198]
#  [0.33676693 0.3529716  0.31026147]
#  [0.33185114 0.37191412 0.29623474]
#  [0.32976272 0.37979648 0.2904408 ]
#  [0.35102353 0.33060563 0.31837084]
#  [0.35501203 0.31730341 0.32768456]
#  [0.35184678 0.31838613 0.32976709]
#  [0.32499924 0.37681507 0.29818569]
#  [0.33980932 0.33507352 0.32511715]]
# [[2.20620335e-03 5.47709494e-02 9.99938173e-01 ... 8.85280484e-01
#   9.99802641e-01 2.19984339e-03]
#  [3.32065203e-03 1.15193507e-01 9.99898165e-01 ... 8.72380379e-01
#   9.99616336e-01 3.13376419e-03]
#  [3.29599323e-03 7.07027844e-02 9.99862788e-01 ... 8.76589926e-01
#   9.99590864e-01 3.54884611e-03]
#  ...
#  [2.28476327e-03 9.49362962e-01 9.99999927e-01 ... 5.33909912e-01
#   9.97165860e-01 7.62401224e-05]
#  [2.35192202e-03 9.15238663e-01 9.99999935e-01 ... 5.05156210e-01
#   9.95516277e-01 6.63067405e-05]
#  [2.90690830e-03 9.27129629e-01 9.99999795e-01 ... 5.03677114e-01
#   9.93614431e-01 1.41687390e-04]]
# [[0.16210482 0.58770126 0.25019392]
#  [0.17510328 0.56323206 0.26166467]
#  [0.165185   0.58172499 0.25309001]
#  [0.17026056 0.57076779 0.25897165]
#  [0.1598159  0.59182545 0.24835864]
#  [0.15959552 0.59166704 0.24873744]
#  [0.16145805 0.58786028 0.25068167]
#  [0.16473854 0.58187681 0.25338465]
#  [0.17378016 0.56479673 0.26142311]
#  [0.17266994 0.56696811 0.26036196]
#  [0.16088483 0.5901429  0.24897227]
#  [0.16452966 0.58110186 0.25436848]
#  [0.17352008 0.56595165 0.26052827]
#  [0.1645808  0.58390469 0.25151451]
#  [0.156899   0.60025669 0.24284432]
#  [0.15479346 0.60302499 0.24218155]
#  [0.1573537  0.59823879 0.24440751]
#  [0.16239103 0.58723939 0.25036957]
#  [0.16268168 0.58645582 0.2508625 ]
#  [0.15822191 0.59461046 0.24716764]
#  [0.1708221  0.57026256 0.25891534]
#  [0.159894   0.59150103 0.24860498]
#  [0.15618298 0.60034027 0.24347675]
#  [0.17307378 0.56569757 0.26122865]
#  [0.16868173 0.57100042 0.26031785]
#  [0.18101309 0.5513709  0.26761601]
#  [0.16676623 0.5776115  0.25562227]
#  [0.16371011 0.58429361 0.25199628]
#  [0.16489886 0.58267639 0.25242475]
#  [0.16949726 0.57162387 0.25887888]
#  [0.17415219 0.56330535 0.26254246]
#  [0.16847896 0.57612238 0.25539866]
#  [0.15519415 0.60064108 0.24416477]
#  [0.15515198 0.60210001 0.242748  ]
#  [0.17318802 0.56602259 0.26078939]
#  [0.16603263 0.58132205 0.25264532]
#  [0.16339637 0.58673868 0.24986495]
#  [0.15912236 0.59290496 0.24797268]
#  [0.16845338 0.57524291 0.25630371]
#  [0.1654362  0.58080997 0.25375383]
#  [0.1609567  0.59031213 0.24873117]
#  [0.20973541 0.50298504 0.28727955]
#  [0.16313529 0.58507542 0.25178929]
#  [0.16485623 0.58149788 0.25364589]
#  [0.16132757 0.58609134 0.25258108]
#  [0.17458554 0.56398777 0.26142669]
#  [0.15859807 0.59315514 0.24824679]
#  [0.16572531 0.57986958 0.25440512]
#  [0.1603879  0.59084329 0.24876881]
#  [0.16603169 0.58010866 0.25385966]
#  [0.36310928 0.26390264 0.37298808]
#  [0.34703261 0.28851602 0.36445136]
#  [0.36575763 0.26325411 0.37098826]
#  [0.36126218 0.27654765 0.36219016]
#  [0.36667772 0.26625112 0.36707116]
#  [0.34867479 0.28956524 0.36175996]
#  [0.341744   0.29874615 0.35950985]
#  [0.32839894 0.31297619 0.35862487]
#  [0.36579707 0.26126605 0.37293688]
#  [0.33247059 0.3150285  0.35250091]
#  [0.35972564 0.2739463  0.36632806]
#  [0.34006379 0.30133694 0.35859927]
#  [0.37432155 0.2513569  0.37432155]
#  [0.35494135 0.28138359 0.36367506]
#  [0.31895242 0.32703775 0.35400982]
#  [0.35772101 0.27276673 0.36951226]
#  [0.33521115 0.31341225 0.35137661]
#  [0.35207511 0.2767323  0.37119259]
#  [0.37114252 0.26873662 0.36012086]
#  [0.3552262  0.27677244 0.36800136]
#  [0.3339546  0.32525547 0.34078994]
#  [0.35311896 0.28052524 0.36635579]
#  [0.36372728 0.27837785 0.35789487]
#  [0.35881565 0.27107102 0.37011333]
#  [0.35942189 0.2705491  0.37002902]
#  [0.36055508 0.26981367 0.36963125]
#  [0.37156889 0.25603939 0.37239173]
#  [0.36272063 0.27664232 0.36063705]
#  [0.35175227 0.28813037 0.36011736]
#  [0.34156764 0.29425439 0.36417797]
#  [0.35655093 0.27610143 0.36734764]
#  [0.35481991 0.27659929 0.3685808 ]
#  [0.34931097 0.28482942 0.36585962]
#  [0.34877598 0.30897016 0.34225387]
#  [0.32838008 0.32544529 0.34617463]
#  [0.32120168 0.32650255 0.35229577]
#  [0.36123083 0.26979883 0.36897034]
#  [0.37470339 0.25543834 0.36985826]
#  [0.32795849 0.31365559 0.35838591]
#  [0.3538337  0.28419538 0.36197093]
#  [0.35127481 0.28601263 0.36271256]
#  [0.350825   0.28493937 0.36423563]
#  [0.35647156 0.27604541 0.36748304]
#  [0.33933405 0.29895415 0.3617118 ]
#  [0.34875799 0.28920082 0.36204119]
#  [0.33330257 0.30371951 0.36297792]
#  [0.34040587 0.29763736 0.36195677]
#  [0.35493918 0.27670187 0.36835896]
#  [0.31366958 0.33570403 0.35062639]
#  [0.34476017 0.29250888 0.36273094]
#  [0.30643232 0.41730686 0.27626082]
#  [0.33573126 0.34667481 0.31759393]
#  [0.34487571 0.3299123  0.32521199]
#  [0.33849824 0.33584193 0.32565983]
#  [0.32733636 0.37108116 0.30158247]
#  [0.33276312 0.35344889 0.313788  ]
#  [0.32576074 0.35581592 0.31842334]
#  [0.34290225 0.32456815 0.3325296 ]
#  [0.34078848 0.33580184 0.32340968]
#  [0.33162236 0.36098126 0.30739638]
#  [0.34870882 0.30954345 0.34174773]
#  [0.34845179 0.32091956 0.33062865]
#  [0.34923004 0.32054978 0.33022018]
#  [0.33339176 0.3582559  0.30835234]
#  [0.32129486 0.39044491 0.28826023]
#  [0.33571516 0.34984682 0.31443802]
#  [0.34710973 0.31495823 0.33793204]
#  [0.33583791 0.33982974 0.32433235]
#  [0.31260576 0.40199115 0.28540309]
#  [0.35426148 0.30260347 0.34313505]
#  [0.34092384 0.34159098 0.31748517]
#  [0.33043877 0.35654275 0.31301848]
#  [0.33177892 0.35346079 0.3147603 ]
#  [0.35798498 0.29601119 0.34600383]
#  [0.33917677 0.33643192 0.32439131]
#  [0.35179201 0.30153668 0.34667131]
#  [0.35568646 0.29734395 0.34696958]
#  [0.34708556 0.30936534 0.34354911]
#  [0.33332258 0.35829898 0.30837845]
#  [0.36028561 0.27971946 0.35999493]
#  [0.34930432 0.31490583 0.33578985]
#  [0.35380881 0.29215875 0.35403244]
#  [0.33045174 0.36737588 0.30217239]
#  [0.35723447 0.28588757 0.35687796]
#  [0.34162508 0.32001492 0.33836   ]
#  [0.34930427 0.32471992 0.32597581]
#  [0.31903022 0.38500029 0.29596949]
#  [0.34345234 0.32036564 0.33618202]
#  [0.34500302 0.31193682 0.34306017]
#  [0.35430595 0.30706008 0.33863397]
#  [0.33512954 0.35884226 0.3060282 ]
#  [0.35727551 0.30564144 0.33708305]
#  [0.33573126 0.34667481 0.31759393]
#  [0.33111996 0.36307401 0.30580603]
#  [0.32858889 0.37201104 0.29940007]
#  [0.35016089 0.32402663 0.32581248]
#  [0.35462689 0.31088552 0.33448759]
#  [0.35045929 0.31308348 0.33645723]
#  [0.32233818 0.37205289 0.30560893]
#  [0.33768955 0.33093325 0.3313772 ]]
# Autograd ArrayBox with value [[2.20620335e-03 5.47709494e-02 9.99938173e-01 ... 8.85280484e-01
#   9.99802641e-01 2.19984339e-03]
#  [3.32065203e-03 1.15193507e-01 9.99898165e-01 ... 8.72380379e-01
#   9.99616336e-01 3.13376419e-03]
#  [3.29599323e-03 7.07027844e-02 9.99862788e-01 ... 8.76589926e-01
#   9.99590864e-01 3.54884611e-03]
#  ...
#  [2.28476327e-03 9.49362962e-01 9.99999927e-01 ... 5.33909912e-01
#   9.97165860e-01 7.62401224e-05]
#  [2.35192202e-03 9.15238663e-01 9.99999935e-01 ... 5.05156210e-01
#   9.95516277e-01 6.63067405e-05]
#  [2.90690830e-03 9.27129629e-01 9.99999795e-01 ... 5.03677114e-01
#   9.93614431e-01 1.41687390e-04]]
# Autograd ArrayBox with value [[0.16210482 0.58770126 0.25019392]
#  [0.17510328 0.56323206 0.26166467]
#  [0.165185   0.58172499 0.25309001]
#  [0.17026056 0.57076779 0.25897165]
#  [0.1598159  0.59182545 0.24835864]
#  [0.15959552 0.59166704 0.24873744]
#  [0.16145805 0.58786028 0.25068167]
#  [0.16473854 0.58187681 0.25338465]
#  [0.17378016 0.56479673 0.26142311]
#  [0.17266994 0.56696811 0.26036196]
#  [0.16088483 0.5901429  0.24897227]
#  [0.16452966 0.58110186 0.25436848]
#  [0.17352008 0.56595165 0.26052827]
#  [0.1645808  0.58390469 0.25151451]
#  [0.156899   0.60025669 0.24284432]
#  [0.15479346 0.60302499 0.24218155]
#  [0.1573537  0.59823879 0.24440751]
#  [0.16239103 0.58723939 0.25036957]
#  [0.16268168 0.58645582 0.2508625 ]
#  [0.15822191 0.59461046 0.24716764]
#  [0.1708221  0.57026256 0.25891534]
#  [0.159894   0.59150103 0.24860498]
#  [0.15618298 0.60034027 0.24347675]
#  [0.17307378 0.56569757 0.26122865]
#  [0.16868173 0.57100042 0.26031785]
#  [0.18101309 0.5513709  0.26761601]
#  [0.16676623 0.5776115  0.25562227]
#  [0.16371011 0.58429361 0.25199628]
#  [0.16489886 0.58267639 0.25242475]
#  [0.16949726 0.57162387 0.25887888]
#  [0.17415219 0.56330535 0.26254246]
#  [0.16847896 0.57612238 0.25539866]
#  [0.15519415 0.60064108 0.24416477]
#  [0.15515198 0.60210001 0.242748  ]
#  [0.17318802 0.56602259 0.26078939]
#  [0.16603263 0.58132205 0.25264532]
#  [0.16339637 0.58673868 0.24986495]
#  [0.15912236 0.59290496 0.24797268]
#  [0.16845338 0.57524291 0.25630371]
#  [0.1654362  0.58080997 0.25375383]
#  [0.1609567  0.59031213 0.24873117]
#  [0.20973541 0.50298504 0.28727955]
#  [0.16313529 0.58507542 0.25178929]
#  [0.16485623 0.58149788 0.25364589]
#  [0.16132757 0.58609134 0.25258108]
#  [0.17458554 0.56398777 0.26142669]
#  [0.15859807 0.59315514 0.24824679]
#  [0.16572531 0.57986958 0.25440512]
#  [0.1603879  0.59084329 0.24876881]
#  [0.16603169 0.58010866 0.25385966]
#  [0.36310928 0.26390264 0.37298808]
#  [0.34703261 0.28851602 0.36445136]
#  [0.36575763 0.26325411 0.37098826]
#  [0.36126218 0.27654765 0.36219016]
#  [0.36667772 0.26625112 0.36707116]
#  [0.34867479 0.28956524 0.36175996]
#  [0.341744   0.29874615 0.35950985]
#  [0.32839894 0.31297619 0.35862487]
#  [0.36579707 0.26126605 0.37293688]
#  [0.33247059 0.3150285  0.35250091]
#  [0.35972564 0.2739463  0.36632806]
#  [0.34006379 0.30133694 0.35859927]
#  [0.37432155 0.2513569  0.37432155]
#  [0.35494135 0.28138359 0.36367506]
#  [0.31895242 0.32703775 0.35400982]
#  [0.35772101 0.27276673 0.36951226]
#  [0.33521115 0.31341225 0.35137661]
#  [0.35207511 0.2767323  0.37119259]
#  [0.37114252 0.26873662 0.36012086]
#  [0.3552262  0.27677244 0.36800136]
#  [0.3339546  0.32525547 0.34078994]
#  [0.35311896 0.28052524 0.36635579]
#  [0.36372728 0.27837785 0.35789487]
#  [0.35881565 0.27107102 0.37011333]
#  [0.35942189 0.2705491  0.37002902]
#  [0.36055508 0.26981367 0.36963125]
#  [0.37156889 0.25603939 0.37239173]
#  [0.36272063 0.27664232 0.36063705]
#  [0.35175227 0.28813037 0.36011736]
#  [0.34156764 0.29425439 0.36417797]
#  [0.35655093 0.27610143 0.36734764]
#  [0.35481991 0.27659929 0.3685808 ]
#  [0.34931097 0.28482942 0.36585962]
#  [0.34877598 0.30897016 0.34225387]
#  [0.32838008 0.32544529 0.34617463]
#  [0.32120168 0.32650255 0.35229577]
#  [0.36123083 0.26979883 0.36897034]
#  [0.37470339 0.25543834 0.36985826]
#  [0.32795849 0.31365559 0.35838591]
#  [0.3538337  0.28419538 0.36197093]
#  [0.35127481 0.28601263 0.36271256]
#  [0.350825   0.28493937 0.36423563]
#  [0.35647156 0.27604541 0.36748304]
#  [0.33933405 0.29895415 0.3617118 ]
#  [0.34875799 0.28920082 0.36204119]
#  [0.33330257 0.30371951 0.36297792]
#  [0.34040587 0.29763736 0.36195677]
#  [0.35493918 0.27670187 0.36835896]
#  [0.31366958 0.33570403 0.35062639]
#  [0.34476017 0.29250888 0.36273094]
#  [0.30643232 0.41730686 0.27626082]
#  [0.33573126 0.34667481 0.31759393]
#  [0.34487571 0.3299123  0.32521199]
#  [0.33849824 0.33584193 0.32565983]
#  [0.32733636 0.37108116 0.30158247]
#  [0.33276312 0.35344889 0.313788  ]
#  [0.32576074 0.35581592 0.31842334]
#  [0.34290225 0.32456815 0.3325296 ]
#  [0.34078848 0.33580184 0.32340968]
#  [0.33162236 0.36098126 0.30739638]
#  [0.34870882 0.30954345 0.34174773]
#  [0.34845179 0.32091956 0.33062865]
#  [0.34923004 0.32054978 0.33022018]
#  [0.33339176 0.3582559  0.30835234]
#  [0.32129486 0.39044491 0.28826023]
#  [0.33571516 0.34984682 0.31443802]
#  [0.34710973 0.31495823 0.33793204]
#  [0.33583791 0.33982974 0.32433235]
#  [0.31260576 0.40199115 0.28540309]
#  [0.35426148 0.30260347 0.34313505]
#  [0.34092384 0.34159098 0.31748517]
#  [0.33043877 0.35654275 0.31301848]
#  [0.33177892 0.35346079 0.3147603 ]
#  [0.35798498 0.29601119 0.34600383]
#  [0.33917677 0.33643192 0.32439131]
#  [0.35179201 0.30153668 0.34667131]
#  [0.35568646 0.29734395 0.34696958]
#  [0.34708556 0.30936534 0.34354911]
#  [0.33332258 0.35829898 0.30837845]
#  [0.36028561 0.27971946 0.35999493]
#  [0.34930432 0.31490583 0.33578985]
#  [0.35380881 0.29215875 0.35403244]
#  [0.33045174 0.36737588 0.30217239]
#  [0.35723447 0.28588757 0.35687796]
#  [0.34162508 0.32001492 0.33836   ]
#  [0.34930427 0.32471992 0.32597581]
#  [0.31903022 0.38500029 0.29596949]
#  [0.34345234 0.32036564 0.33618202]
#  [0.34500302 0.31193682 0.34306017]
#  [0.35430595 0.30706008 0.33863397]
#  [0.33512954 0.35884226 0.3060282 ]
#  [0.35727551 0.30564144 0.33708305]
#  [0.33573126 0.34667481 0.31759393]
#  [0.33111996 0.36307401 0.30580603]
#  [0.32858889 0.37201104 0.29940007]
#  [0.35016089 0.32402663 0.32581248]
#  [0.35462689 0.31088552 0.33448759]
#  [0.35045929 0.31308348 0.33645723]
#  [0.32233818 0.37205289 0.30560893]
#  [0.33768955 0.33093325 0.3313772 ]]
# [[2.21017412e-03 4.70016816e-02 9.99938196e-01 ... 8.73991126e-01
#   9.99801713e-01 2.20084044e-03]
#  [3.32644961e-03 1.00375805e-01 9.99898200e-01 ... 8.60605144e-01
#   9.99614625e-01 3.13508990e-03]
#  [3.30147700e-03 6.15200260e-02 9.99862835e-01 ... 8.65523035e-01
#   9.99589087e-01 3.55032717e-03]
#  ...
#  [2.29274341e-03 9.33584224e-01 9.99999927e-01 ... 4.86240140e-01
#   9.97142888e-01 7.62836055e-05]
#  [2.36016141e-03 8.89782149e-01 9.99999935e-01 ... 4.56884922e-01
#   9.95479351e-01 6.63445822e-05]
#  [2.91646663e-03 9.06503504e-01 9.99999795e-01 ... 4.58703623e-01
#   9.93565684e-01 1.41763109e-04]]
# [[0.16896485 0.58806756 0.24296759]
#  [0.18036209 0.566634   0.25300391]
#  [0.17173194 0.58271248 0.24555558]
#  [0.17597873 0.57311365 0.25090761]
#  [0.16697054 0.5915873  0.24144216]
#  [0.16656646 0.59159302 0.24184051]
#  [0.16834923 0.58804473 0.24360604]
#  [0.17114329 0.5830033  0.24585341]
#  [0.17924315 0.56768535 0.2530715 ]
#  [0.1780941  0.56994395 0.25196195]
#  [0.16784906 0.59027531 0.24187563]
#  [0.17083653 0.58225383 0.24690964]
#  [0.17898124 0.56894141 0.25207736]
#  [0.171391   0.5844692  0.2441398 ]
#  [0.16474192 0.59902181 0.23623626]
#  [0.162757   0.60129842 0.23594458]
#  [0.16500647 0.59722433 0.23776921]
#  [0.16921426 0.58768505 0.24310068]
#  [0.16922453 0.58728415 0.24349132]
#  [0.16552612 0.59400841 0.24046546]
#  [0.1761956  0.57324407 0.25056033]
#  [0.16696549 0.59136291 0.2416716 ]
#  [0.16407691 0.59891519 0.2370079 ]
#  [0.17815079 0.5691703  0.25267891]
#  [0.17407256 0.57354274 0.2523847 ]
#  [0.18529662 0.55638139 0.258322  ]
#  [0.17279226 0.57937051 0.24783724]
#  [0.17026406 0.58517916 0.24455678]
#  [0.17139734 0.58377331 0.24482935]
#  [0.17517882 0.57395161 0.25086957]
#  [0.17926983 0.56672609 0.25400409]
#  [0.17439786 0.57829445 0.24730769]
#  [0.16295334 0.59915604 0.23789062]
#  [0.16307035 0.60048294 0.23644671]
#  [0.17854349 0.56913502 0.25232149]
#  [0.17258434 0.582469   0.24494666]
#  [0.17020439 0.58739351 0.24240211]
#  [0.16635292 0.59248309 0.24116399]
#  [0.17462143 0.57689232 0.24848626]
#  [0.17175523 0.5821277  0.24611707]
#  [0.16805292 0.59029672 0.24165036]
#  [0.21194674 0.51168337 0.27636989]
#  [0.16990664 0.58554384 0.24454952]
#  [0.17113393 0.58277758 0.24608849]
#  [0.16777409 0.58671459 0.24551132]
#  [0.17990702 0.56725297 0.25284001]
#  [0.16574967 0.59273872 0.24151162]
#  [0.17209675 0.58106724 0.24683601]
#  [0.16741028 0.59083734 0.24175239]
#  [0.17237828 0.58145462 0.24616711]
#  [0.3575834  0.27134506 0.37107154]
#  [0.34012944 0.29797274 0.36189783]
#  [0.36183184 0.26681002 0.37135815]
#  [0.35911429 0.27891588 0.36196983]
#  [0.36373993 0.26870627 0.3675538 ]
#  [0.34447742 0.29345522 0.36206736]
#  [0.33473894 0.30692359 0.35833747]
#  [0.32312115 0.32429176 0.35258709]
#  [0.36192031 0.26599969 0.37208   ]
#  [0.32686901 0.32327949 0.3498515 ]
#  [0.35770687 0.27827406 0.36401907]
#  [0.33346053 0.31086399 0.35567548]
#  [0.37282271 0.25435459 0.37282271]
#  [0.35110033 0.28423772 0.36466195]
#  [0.31120611 0.3421524  0.34664149]
#  [0.35164115 0.28192397 0.36643488]
#  [0.32952395 0.31908196 0.35139409]
#  [0.34708107 0.28484382 0.36807512]
#  [0.37103179 0.26608474 0.36288347]
#  [0.35121106 0.28353696 0.36525198]
#  [0.32847544 0.32854846 0.3429761 ]
#  [0.34760719 0.28977096 0.36262185]
#  [0.36312221 0.2747855  0.36209229]
#  [0.35543024 0.27381792 0.37075184]
#  [0.35435351 0.27818225 0.36746425]
#  [0.35530028 0.27744088 0.36725883]
#  [0.36922237 0.25755567 0.37322196]
#  [0.36005797 0.27644437 0.36349766]
#  [0.3472723  0.29251934 0.36020836]
#  [0.33564186 0.30643593 0.35792221]
#  [0.35295142 0.28242826 0.36462032]
#  [0.35085283 0.28419604 0.36495113]
#  [0.3439356  0.29407082 0.36199357]
#  [0.34789762 0.30377767 0.34832471]
#  [0.3225677  0.33094574 0.34648656]
#  [0.31219384 0.33913814 0.34866802]
#  [0.35640824 0.27532296 0.3682688 ]
#  [0.373813   0.25555818 0.37062882]
#  [0.3205565  0.32538027 0.35406323]
#  [0.35025906 0.28904008 0.36070087]
#  [0.3480115  0.28865423 0.36333427]
#  [0.34576342 0.29038528 0.36385131]
#  [0.35224924 0.28281769 0.36493306]
#  [0.33478958 0.30881546 0.35639495]
#  [0.3442805  0.29486088 0.36085862]
#  [0.32614764 0.314819   0.35903336]
#  [0.33426952 0.30650717 0.35922331]
#  [0.3496405  0.28441475 0.36594476]
#  [0.3076046  0.35034445 0.34205095]
#  [0.33917489 0.30083894 0.35998616]
#  [0.30526116 0.4100768  0.28466204]
#  [0.33527488 0.33968917 0.32503596]
#  [0.34566417 0.31908643 0.3352494 ]
#  [0.33843527 0.32725163 0.3343131 ]
#  [0.32777747 0.36088003 0.3113425 ]
#  [0.33467354 0.33942175 0.32590472]
#  [0.32385554 0.35282693 0.32331752]
#  [0.34422449 0.3124855  0.34329001]
#  [0.34232921 0.32431862 0.33335217]
#  [0.33085153 0.35140811 0.31774036]
#  [0.34544531 0.30814917 0.34640552]
#  [0.34868236 0.31280659 0.33851104]
#  [0.34902642 0.31246038 0.3385132 ]
#  [0.33365449 0.35025945 0.31608607]
#  [0.32062821 0.38348559 0.2958862 ]
#  [0.33387208 0.34415399 0.32197393]
#  [0.34628072 0.30827152 0.34544776]
#  [0.33566553 0.32844789 0.33588658]
#  [0.31450508 0.38883038 0.29666454]
#  [0.35497142 0.29533971 0.34968886]
#  [0.34069964 0.33244404 0.32685633]
#  [0.32881179 0.35175635 0.31943186]
#  [0.33397195 0.33898201 0.32704604]
#  [0.35695983 0.29206677 0.3509734 ]
#  [0.33792148 0.32912462 0.3329539 ]
#  [0.35138866 0.29340082 0.35521053]
#  [0.35372052 0.29528004 0.35099944]
#  [0.34396747 0.30848953 0.347543  ]
#  [0.33403919 0.34812641 0.3178344 ]
#  [0.35969841 0.27358977 0.36671181]
#  [0.35055858 0.3034108  0.34603062]
#  [0.35183687 0.2857954  0.36236773]
#  [0.33121955 0.35709577 0.31168468]
#  [0.35564307 0.28301939 0.36133754]
#  [0.3420913  0.31131005 0.34659866]
#  [0.35067397 0.31243253 0.3368935 ]
#  [0.31670094 0.3792077  0.30409137]
#  [0.34203461 0.31447702 0.34348837]
#  [0.34141841 0.31213269 0.3464489 ]
#  [0.35324888 0.30107427 0.34567685]
#  [0.33516682 0.34938203 0.31545115]
#  [0.35566064 0.30146456 0.34287479]
#  [0.33527488 0.33968917 0.32503596]
#  [0.33131053 0.35280391 0.31588556]
#  [0.32790256 0.36334131 0.30875613]
#  [0.3494737  0.31732454 0.33320177]
#  [0.35498754 0.3036786  0.34133386]
#  [0.34905781 0.3080617  0.34288049]
#  [0.31903587 0.36825082 0.31271331]
#  [0.3352607  0.3275278  0.3372115 ]]
# Autograd ArrayBox with value [[2.21017412e-03 4.70016816e-02 9.99938196e-01 ... 8.73991126e-01
#   9.99801713e-01 2.20084044e-03]
#  [3.32644961e-03 1.00375805e-01 9.99898200e-01 ... 8.60605144e-01
#   9.99614625e-01 3.13508990e-03]
#  [3.30147700e-03 6.15200260e-02 9.99862835e-01 ... 8.65523035e-01
#   9.99589087e-01 3.55032717e-03]
#  ...
#  [2.29274341e-03 9.33584224e-01 9.99999927e-01 ... 4.86240140e-01
#   9.97142888e-01 7.62836055e-05]
#  [2.36016141e-03 8.89782149e-01 9.99999935e-01 ... 4.56884922e-01
#   9.95479351e-01 6.63445822e-05]
#  [2.91646663e-03 9.06503504e-01 9.99999795e-01 ... 4.58703623e-01
#   9.93565684e-01 1.41763109e-04]]
# Autograd ArrayBox with value [[0.16896485 0.58806756 0.24296759]
#  [0.18036209 0.566634   0.25300391]
#  [0.17173194 0.58271248 0.24555558]
#  [0.17597873 0.57311365 0.25090761]
#  [0.16697054 0.5915873  0.24144216]
#  [0.16656646 0.59159302 0.24184051]
#  [0.16834923 0.58804473 0.24360604]
#  [0.17114329 0.5830033  0.24585341]
#  [0.17924315 0.56768535 0.2530715 ]
#  [0.1780941  0.56994395 0.25196195]
#  [0.16784906 0.59027531 0.24187563]
#  [0.17083653 0.58225383 0.24690964]
#  [0.17898124 0.56894141 0.25207736]
#  [0.171391   0.5844692  0.2441398 ]
#  [0.16474192 0.59902181 0.23623626]
#  [0.162757   0.60129842 0.23594458]
#  [0.16500647 0.59722433 0.23776921]
#  [0.16921426 0.58768505 0.24310068]
#  [0.16922453 0.58728415 0.24349132]
#  [0.16552612 0.59400841 0.24046546]
#  [0.1761956  0.57324407 0.25056033]
#  [0.16696549 0.59136291 0.2416716 ]
#  [0.16407691 0.59891519 0.2370079 ]
#  [0.17815079 0.5691703  0.25267891]
#  [0.17407256 0.57354274 0.2523847 ]
#  [0.18529662 0.55638139 0.258322  ]
#  [0.17279226 0.57937051 0.24783724]
#  [0.17026406 0.58517916 0.24455678]
#  [0.17139734 0.58377331 0.24482935]
#  [0.17517882 0.57395161 0.25086957]
#  [0.17926983 0.56672609 0.25400409]
#  [0.17439786 0.57829445 0.24730769]
#  [0.16295334 0.59915604 0.23789062]
#  [0.16307035 0.60048294 0.23644671]
#  [0.17854349 0.56913502 0.25232149]
#  [0.17258434 0.582469   0.24494666]
#  [0.17020439 0.58739351 0.24240211]
#  [0.16635292 0.59248309 0.24116399]
#  [0.17462143 0.57689232 0.24848626]
#  [0.17175523 0.5821277  0.24611707]
#  [0.16805292 0.59029672 0.24165036]
#  [0.21194674 0.51168337 0.27636989]
#  [0.16990664 0.58554384 0.24454952]
#  [0.17113393 0.58277758 0.24608849]
#  [0.16777409 0.58671459 0.24551132]
#  [0.17990702 0.56725297 0.25284001]
#  [0.16574967 0.59273872 0.24151162]
#  [0.17209675 0.58106724 0.24683601]
#  [0.16741028 0.59083734 0.24175239]
#  [0.17237828 0.58145462 0.24616711]
#  [0.3575834  0.27134506 0.37107154]
#  [0.34012944 0.29797274 0.36189783]
#  [0.36183184 0.26681002 0.37135815]
#  [0.35911429 0.27891588 0.36196983]
#  [0.36373993 0.26870627 0.3675538 ]
#  [0.34447742 0.29345522 0.36206736]
#  [0.33473894 0.30692359 0.35833747]
#  [0.32312115 0.32429176 0.35258709]
#  [0.36192031 0.26599969 0.37208   ]
#  [0.32686901 0.32327949 0.3498515 ]
#  [0.35770687 0.27827406 0.36401907]
#  [0.33346053 0.31086399 0.35567548]
#  [0.37282271 0.25435459 0.37282271]
#  [0.35110033 0.28423772 0.36466195]
#  [0.31120611 0.3421524  0.34664149]
#  [0.35164115 0.28192397 0.36643488]
#  [0.32952395 0.31908196 0.35139409]
#  [0.34708107 0.28484382 0.36807512]
#  [0.37103179 0.26608474 0.36288347]
#  [0.35121106 0.28353696 0.36525198]
#  [0.32847544 0.32854846 0.3429761 ]
#  [0.34760719 0.28977096 0.36262185]
#  [0.36312221 0.2747855  0.36209229]
#  [0.35543024 0.27381792 0.37075184]
#  [0.35435351 0.27818225 0.36746425]
#  [0.35530028 0.27744088 0.36725883]
#  [0.36922237 0.25755567 0.37322196]
#  [0.36005797 0.27644437 0.36349766]
#  [0.3472723  0.29251934 0.36020836]
#  [0.33564186 0.30643593 0.35792221]
#  [0.35295142 0.28242826 0.36462032]
#  [0.35085283 0.28419604 0.36495113]
#  [0.3439356  0.29407082 0.36199357]
#  [0.34789762 0.30377767 0.34832471]
#  [0.3225677  0.33094574 0.34648656]
#  [0.31219384 0.33913814 0.34866802]
#  [0.35640824 0.27532296 0.3682688 ]
#  [0.373813   0.25555818 0.37062882]
#  [0.3205565  0.32538027 0.35406323]
#  [0.35025906 0.28904008 0.36070087]
#  [0.3480115  0.28865423 0.36333427]
#  [0.34576342 0.29038528 0.36385131]
#  [0.35224924 0.28281769 0.36493306]
#  [0.33478958 0.30881546 0.35639495]
#  [0.3442805  0.29486088 0.36085862]
#  [0.32614764 0.314819   0.35903336]
#  [0.33426952 0.30650717 0.35922331]
#  [0.3496405  0.28441475 0.36594476]
#  [0.3076046  0.35034445 0.34205095]
#  [0.33917489 0.30083894 0.35998616]
#  [0.30526116 0.4100768  0.28466204]
#  [0.33527488 0.33968917 0.32503596]
#  [0.34566417 0.31908643 0.3352494 ]
#  [0.33843527 0.32725163 0.3343131 ]
#  [0.32777747 0.36088003 0.3113425 ]
#  [0.33467354 0.33942175 0.32590472]
#  [0.32385554 0.35282693 0.32331752]
#  [0.34422449 0.3124855  0.34329001]
#  [0.34232921 0.32431862 0.33335217]
#  [0.33085153 0.35140811 0.31774036]
#  [0.34544531 0.30814917 0.34640552]
#  [0.34868236 0.31280659 0.33851104]
#  [0.34902642 0.31246038 0.3385132 ]
#  [0.33365449 0.35025945 0.31608607]
#  [0.32062821 0.38348559 0.2958862 ]
#  [0.33387208 0.34415399 0.32197393]
#  [0.34628072 0.30827152 0.34544776]
#  [0.33566553 0.32844789 0.33588658]
#  [0.31450508 0.38883038 0.29666454]
#  [0.35497142 0.29533971 0.34968886]
#  [0.34069964 0.33244404 0.32685633]
#  [0.32881179 0.35175635 0.31943186]
#  [0.33397195 0.33898201 0.32704604]
#  [0.35695983 0.29206677 0.3509734 ]
#  [0.33792148 0.32912462 0.3329539 ]
#  [0.35138866 0.29340082 0.35521053]
#  [0.35372052 0.29528004 0.35099944]
#  [0.34396747 0.30848953 0.347543  ]
#  [0.33403919 0.34812641 0.3178344 ]
#  [0.35969841 0.27358977 0.36671181]
#  [0.35055858 0.3034108  0.34603062]
#  [0.35183687 0.2857954  0.36236773]
#  [0.33121955 0.35709577 0.31168468]
#  [0.35564307 0.28301939 0.36133754]
#  [0.3420913  0.31131005 0.34659866]
#  [0.35067397 0.31243253 0.3368935 ]
#  [0.31670094 0.3792077  0.30409137]
#  [0.34203461 0.31447702 0.34348837]
#  [0.34141841 0.31213269 0.3464489 ]
#  [0.35324888 0.30107427 0.34567685]
#  [0.33516682 0.34938203 0.31545115]
#  [0.35566064 0.30146456 0.34287479]
#  [0.33527488 0.33968917 0.32503596]
#  [0.33131053 0.35280391 0.31588556]
#  [0.32790256 0.36334131 0.30875613]
#  [0.3494737  0.31732454 0.33320177]
#  [0.35498754 0.3036786  0.34133386]
#  [0.34905781 0.3080617  0.34288049]
#  [0.31903587 0.36825082 0.31271331]
#  [0.3352607  0.3275278  0.3372115 ]]
# [[2.21414112e-03 3.75410244e-02 9.99938218e-01 ... 8.62361804e-01
#   9.99800795e-01 2.20185202e-03]
#  [3.33224321e-03 8.19209135e-02 9.99898235e-01 ... 8.48534486e-01
#   9.99612933e-01 3.13643493e-03]
#  [3.30695499e-03 5.01333382e-02 9.99862881e-01 ... 8.54206991e-01
#   9.99587331e-01 3.55182976e-03]
#  ...
#  [2.30075810e-03 9.04577773e-01 9.99999927e-01 ... 4.40324390e-01
#   9.97120070e-01 7.63277606e-05]
#  [2.36843735e-03 8.44376757e-01 9.99999935e-01 ... 4.10893098e-01
#   9.95442665e-01 6.63830105e-05]
#  [2.92606493e-03 8.69930649e-01 9.99999795e-01 ... 4.15784061e-01
#   9.93517286e-01 1.41839997e-04]]
# [[0.17743009 0.58525679 0.23731312]
#  [0.18678708 0.56758962 0.2456233 ]
#  [0.1797727  0.58071945 0.23950785]
#  [0.18299026 0.57278801 0.24422173]
#  [0.17580225 0.58805689 0.23614086]
#  [0.17520972 0.58819311 0.23659717]
#  [0.17683859 0.58506445 0.23809696]
#  [0.17904388 0.58111706 0.23983905]
#  [0.18589625 0.5680939  0.24600984]
#  [0.18474585 0.5703566  0.24489755]
#  [0.17646489 0.58714263 0.23639248]
#  [0.17861768 0.58041555 0.24096678]
#  [0.18565278 0.56941147 0.24493575]
#  [0.17972598 0.5820323  0.23824172]
#  [0.17444255 0.5942424  0.23131505]
#  [0.17261334 0.59593919 0.23144747]
#  [0.17446876 0.59272484 0.2328064 ]
#  [0.17763609 0.58496427 0.23739964]
#  [0.17735527 0.58492002 0.23772471]
#  [0.17455634 0.59002334 0.23542031]
#  [0.18286253 0.57351845 0.24361901]
#  [0.17570848 0.58792818 0.23636334]
#  [0.17381432 0.59398354 0.23220214]
#  [0.18444083 0.57007596 0.24548321]
#  [0.18075417 0.57335986 0.24588597]
#  [0.19053253 0.55928757 0.2501799 ]
#  [0.18023933 0.57822639 0.24153428]
#  [0.17836091 0.5829744  0.23866469]
#  [0.17941292 0.58183579 0.23875129]
#  [0.18216759 0.57356965 0.24426276]
#  [0.18555105 0.56768049 0.24676846]
#  [0.18172141 0.5776019  0.24067669]
#  [0.17254801 0.59411861 0.23333337]
#  [0.17286482 0.59526758 0.2318676 ]
#  [0.18511301 0.56970683 0.24518017]
#  [0.18063115 0.58064477 0.23872408]
#  [0.17861138 0.58489432 0.23649431]
#  [0.17527549 0.58874524 0.23597928]
#  [0.18216314 0.57576375 0.24207311]
#  [0.17955322 0.58045998 0.2399868 ]
#  [0.1768048  0.58703657 0.23615863]
#  [0.21428934 0.5197547  0.26595596]
#  [0.17822333 0.58294884 0.23882783]
#  [0.17890205 0.58104075 0.2400572 ]
#  [0.17577929 0.584164   0.24005671]
#  [0.18641036 0.56804616 0.24554348]
#  [0.17459488 0.58897609 0.23642902]
#  [0.1799235  0.57933537 0.24074113]
#  [0.17609453 0.58754987 0.2363556 ]
#  [0.18019242 0.57984819 0.23995939]
#  [0.34826612 0.28385658 0.3678773 ]
#  [0.32890372 0.3137528  0.35734348]
#  [0.3552495  0.27390092 0.37084958]
#  [0.35552966 0.28316883 0.36130151]
#  [0.35877543 0.27380784 0.36741673]
#  [0.33771765 0.30110128 0.36118107]
#  [0.32341696 0.32164854 0.3549345 ]
#  [0.31487683 0.34002087 0.34510229]
#  [0.35544457 0.27411227 0.37044316]
#  [0.31805018 0.33645303 0.34549679]
#  [0.35431314 0.28433025 0.3613566 ]
#  [0.32287917 0.32634433 0.3507765 ]
#  [0.37026318 0.25844921 0.37128761]
#  [0.34481612 0.29059172 0.36459216]
#  [0.29945176 0.36352794 0.3370203 ]
#  [0.34146812 0.29669594 0.36183595]
#  [0.3204453  0.3300185  0.3495362 ]
#  [0.33899915 0.29723743 0.36376342]
#  [0.37095979 0.26332262 0.36571759]
#  [0.34460909 0.29380608 0.36158483]
#  [0.31945525 0.33738135 0.34316341]
#  [0.33848435 0.30402217 0.35749349]
#  [0.36231233 0.2715503  0.36613737]
#  [0.34999669 0.27941188 0.37059142]
#  [0.34587935 0.29041141 0.36370924]
#  [0.34645261 0.2899133  0.36363409]
#  [0.3653818  0.26091193 0.37370627]
#  [0.35555127 0.27883452 0.36561421]
#  [0.33988375 0.30110148 0.35901477]
#  [0.32607747 0.3238017  0.35012083]
#  [0.3469914  0.29191025 0.36109836]
#  [0.34429579 0.2952647  0.3604395 ]
#  [0.33516412 0.30808409 0.35675179]
#  [0.34651371 0.29945175 0.35403455]
#  [0.31339514 0.34179707 0.34480779]
#  [0.29842352 0.35954218 0.3420343 ]
#  [0.34830928 0.28531407 0.36637665]
#  [0.3724184  0.25615372 0.37142788]
#  [0.30913883 0.34336703 0.34749415]
#  [0.34437711 0.29708605 0.35853683]
#  [0.34280787 0.29409585 0.36309628]
#  [0.33750741 0.30045974 0.36203286]
#  [0.34525898 0.29334257 0.36139845]
#  [0.32748085 0.32261709 0.34990206]
#  [0.33703043 0.30451215 0.35845742]
#  [0.31501461 0.33200898 0.35297642]
#  [0.32451474 0.32077371 0.35471155]
#  [0.3409074  0.29689487 0.36219774]
#  [0.29832232 0.36990829 0.33176939]
#  [0.33018888 0.31411993 0.35569118]
#  [0.30416746 0.4023316  0.29350093]
#  [0.33453115 0.33309268 0.33237616]
#  [0.34694134 0.30767683 0.34538183]
#  [0.3383842  0.3187379  0.3428779 ]
#  [0.32870749 0.34975854 0.32153398]
#  [0.33822841 0.32304994 0.33872165]
#  [0.32092074 0.3513895  0.32768977]
#  [0.34672058 0.2990372  0.35424222]
#  [0.34524579 0.3109579  0.34379631]
#  [0.32903122 0.34323669 0.32773209]
#  [0.33965755 0.3105223  0.34982015]
#  [0.3490435  0.30459296 0.34636353]
#  [0.3484485  0.30499799 0.3465535 ]
#  [0.33424723 0.34165079 0.32410198]
#  [0.31971828 0.37657554 0.30370618]
#  [0.33030326 0.34094081 0.32875593]
#  [0.34483979 0.30264737 0.35251284]
#  [0.33500728 0.31801052 0.34698221]
#  [0.31919155 0.3711718  0.30963665]
#  [0.35645034 0.28712916 0.35642051]
#  [0.33994938 0.32403049 0.33602013]
#  [0.32603014 0.34863152 0.32533835]
#  [0.33813365 0.32172147 0.34014488]
#  [0.35515099 0.28929266 0.35555635]
#  [0.33547341 0.32364272 0.34088388]
#  [0.35080824 0.28588457 0.3633072 ]
#  [0.35028155 0.29535903 0.35435942]
#  [0.33862035 0.3109609  0.35041874]
#  [0.33537893 0.33692153 0.32769954]
#  [0.35910272 0.26781882 0.37307846]
#  [0.35291108 0.29067567 0.35641325]
#  [0.34840567 0.28200047 0.36959385]
#  [0.3327109  0.34555453 0.32173457]
#  [0.35313829 0.28157808 0.36528362]
#  [0.34322435 0.30186603 0.35490962]
#  [0.35292305 0.29905364 0.3480233 ]
#  [0.31258917 0.37588639 0.31152444]
#  [0.33955224 0.31031249 0.35013528]
#  [0.33532026 0.31611062 0.34856913]
#  [0.35116221 0.29666728 0.3521705 ]
#  [0.33495709 0.34009883 0.32494409]
#  [0.35236124 0.29968828 0.34795048]
#  [0.33453115 0.33309268 0.33237616]
# ...
#  [0.65217179 0.25700113 0.09082708]
#  [0.67849591 0.23949093 0.08201316]
#  [0.66869307 0.24595854 0.0853484 ]
#  [0.65749347 0.25353517 0.08897136]
#  [0.67107452 0.24441637 0.08450911]
#  [0.68321745 0.23609447 0.08068808]
#  [0.6746467  0.24205412 0.08329918]
#  [0.68924009 0.23196899 0.07879092]
#  [0.68288241 0.23638374 0.08073385]
#  [0.2108604  0.50904497 0.28009464]
#  [0.21228178 0.50276048 0.28495774]
#  [0.19671318 0.5084026  0.29488423]
#  [0.21088727 0.47833854 0.31077418]
#  [0.20054889 0.50169356 0.29775755]
#  [0.19334027 0.48203939 0.32462033]
#  [0.19975267 0.50131358 0.29893375]
#  [0.27643535 0.46267851 0.26088614]
#  [0.2057952  0.50383954 0.29036525]
#  [0.21925391 0.47864605 0.30210005]
#  [0.23922468 0.46331722 0.2974581 ]
#  [0.21877326 0.49453266 0.28669407]
#  [0.22465283 0.48692153 0.28842564]
#  [0.19162176 0.49144173 0.31693651]
#  [0.27514568 0.47592345 0.24893087]
#  [0.22374147 0.50335893 0.27289961]
#  [0.19261498 0.48186395 0.32552106]
#  [0.22415674 0.48957998 0.28626328]
#  [0.19361869 0.48298779 0.32339352]
#  [0.22941757 0.48435076 0.28623167]
#  [0.18422632 0.48561003 0.33016366]
#  [0.23815949 0.49262467 0.26921584]
#  [0.18183923 0.48078697 0.3373738 ]
#  [0.19200136 0.48992614 0.31807249]
#  [0.22180683 0.49998774 0.27820543]
#  [0.21931997 0.50312629 0.27755374]
#  [0.19650249 0.50489071 0.2986068 ]
#  [0.18748301 0.50198961 0.31052737]
#  [0.19892691 0.49331759 0.3077555 ]
#  [0.28626428 0.47096621 0.24276951]
#  [0.23321666 0.4812285  0.28555484]
#  [0.24544378 0.4794928  0.27506342]
#  [0.23901146 0.4880292  0.27295933]
#  [0.1699028  0.46013899 0.3699582 ]
#  [0.18797583 0.47322663 0.33879754]
#  [0.20815294 0.49766306 0.294184  ]
#  [0.20343557 0.5064453  0.29011913]
#  [0.20266436 0.4917477  0.30558795]
#  [0.2231025  0.48859815 0.28829935]
#  [0.21521297 0.4823918  0.30239524]
#  [0.19212045 0.47300436 0.33487519]
#  [0.19820988 0.49531104 0.30647908]
#  [0.22662327 0.48914776 0.28422898]
#  [0.27545764 0.46371822 0.26082414]
#  [0.20755177 0.48506228 0.30738595]
#  [0.21880634 0.49019654 0.29099712]
#  [0.21462849 0.48982203 0.29554948]
#  [0.21785663 0.49804791 0.28409547]
#  [0.33951694 0.4424415  0.21804156]
#  [0.21979309 0.48944107 0.29076584]
#  [0.14626786 0.42756757 0.42616457]
#  [0.162747   0.44582442 0.39142858]
#  [0.16681884 0.47787634 0.35530482]
#  [0.16036982 0.44826058 0.3913696 ]
#  [0.15693017 0.44785607 0.39521376]
#  [0.15992404 0.45811235 0.38196362]
#  [0.16301194 0.42457059 0.41241748]
#  [0.16212387 0.45978672 0.37808941]
#  [0.16106216 0.43987668 0.39906116]
#  [0.16602482 0.48629265 0.34768253]
#  [0.18128324 0.49613999 0.32257677]
#  [0.16943669 0.46848161 0.3620817 ]
#  [0.17171656 0.48598    0.34230344]
#  [0.16106792 0.43775847 0.40117361]
#  [0.15914446 0.44987105 0.39098449]
#  [0.17108573 0.48286226 0.34605202]
#  [0.16839552 0.47209817 0.35950631]
#  [0.16405704 0.48286441 0.35307855]
#  [0.15222658 0.41512084 0.43265259]
#  [0.17108221 0.44342758 0.38549021]
#  [0.16859215 0.48471069 0.34669717]
#  [0.16569996 0.45218925 0.38211078]
#  [0.15932635 0.44801665 0.39265699]
#  [0.18125274 0.48605029 0.33269697]
#  [0.16723102 0.47810104 0.35466794]
#  [0.16875424 0.48461711 0.34662865]
#  [0.18431003 0.48883213 0.32685783]
#  [0.18101706 0.48537666 0.33360628]
#  [0.1597016  0.44945014 0.39084826]
#  [0.17280426 0.4905118  0.33668394]
#  [0.16733229 0.47511055 0.35755717]
#  [0.17223624 0.50589498 0.32186878]
#  [0.15895482 0.44914586 0.39189933]
#  [0.17741158 0.48036653 0.34222189]
#  [0.15584471 0.42131351 0.42284178]
#  [0.17033276 0.49371387 0.33595336]
#  [0.16117725 0.46385544 0.3749673 ]
#  [0.16739867 0.46963687 0.36296446]
#  [0.18321204 0.48557178 0.33121618]
#  [0.17649241 0.496795   0.32671259]
#  [0.16630094 0.47757527 0.35612379]
#  [0.18369599 0.50569429 0.31060971]
#  [0.162747   0.44582442 0.39142858]
#  [0.1616815  0.46668182 0.37163667]
#  [0.164695   0.47694381 0.35836118]
#  [0.17712231 0.4951571  0.32772058]
#  [0.17561441 0.47408678 0.3502988 ]
#  [0.17601478 0.48798674 0.33599847]
#  [0.16621754 0.4718508  0.36193166]
#  [0.16937039 0.46398141 0.3666482 ]]
# Autograd ArrayBox with value [[2.43631179e-03 4.74608033e-04 9.99939632e-01 ... 9.27407146e-01
#   9.97380633e-01 2.29307218e-03]
#  [3.65436235e-03 1.36779274e-03 9.99900410e-01 ... 9.01554667e-01
#   9.95528722e-01 3.25700530e-03]
#  [3.61247428e-03 9.00453013e-04 9.99865776e-01 ... 9.17361930e-01
#   9.95554807e-01 3.68701852e-03]
#  ...
#  [2.75279109e-03 1.08642110e-02 9.99999929e-01 ... 3.32608373e-02
#   8.31574219e-01 8.01673165e-05]
#  [2.83620705e-03 6.05948901e-03 9.99999937e-01 ... 2.59756519e-02
#   7.49841229e-01 6.97318695e-05]
#  [3.46501059e-03 1.14533094e-02 9.99999800e-01 ... 3.36962802e-02
#   7.36844142e-01 1.48514907e-04]]
# Autograd ArrayBox with value [[0.6883298  0.23262628 0.07904392]
#  [0.67415104 0.24236514 0.08348382]
#  [0.68272682 0.23654752 0.08072566]
#  [0.66394959 0.24929247 0.08675795]
#  [0.68912126 0.23208201 0.07879673]
#  [0.68098502 0.23759205 0.08142292]
#  [0.67837523 0.23943461 0.08219016]
#  [0.67885568 0.23912085 0.08202347]
#  [0.66249139 0.25033596 0.08717265]
#  [0.67085085 0.2446551  0.08449405]
#  [0.69036483 0.23119121 0.07844396]
#  [0.66837832 0.24624741 0.08537427]
#  [0.67397134 0.24257097 0.08345769]
#  [0.68612628 0.23453503 0.07933868]
#  [0.70869913 0.21848274 0.07281813]
#  [0.70239469 0.22282937 0.07477594]
#  [0.70060783 0.22410182 0.07529035]
#  [0.68728357 0.23332123 0.0793952 ]
#  [0.68389515 0.23561424 0.0804906 ]
#  [0.68785701 0.23289912 0.07924387]
#  [0.67078788 0.24460266 0.08460946]
#  [0.68469996 0.2350577  0.08024234]
#  [0.70241937 0.22301549 0.07456513]
#  [0.65725511 0.25372109 0.0890238 ]
#  [0.63935189 0.26573158 0.09491653]
#  [0.65966676 0.25215615 0.08817709]
#  [0.66881051 0.24590087 0.08528862]
#  [0.68390789 0.23564718 0.08044493]
#  [0.68752525 0.23317784 0.07929691]
#  [0.66030853 0.25172187 0.08796959]
#  [0.65898845 0.2526168  0.08839475]
#  [0.68200271 0.23692572 0.08107157]
#  [0.69613714 0.22721447 0.07664839]
#  [0.70309837 0.22236766 0.07453396]
#  [0.66934926 0.24561565 0.0850351 ]
#  [0.69181114 0.23028218 0.07790667]
#  [0.69719891 0.22649237 0.07630872]
#  [0.68898903 0.23222408 0.07878689]
#  [0.67339365 0.24298495 0.0836214 ]
#  [0.6802828  0.23814026 0.08157694]
#  [0.69135532 0.23053667 0.07810801]
#  [0.65217179 0.25700113 0.09082708]
#  [0.67849591 0.23949093 0.08201316]
#  [0.66869307 0.24595854 0.0853484 ]
#  [0.65749347 0.25353517 0.08897136]
#  [0.67107452 0.24441637 0.08450911]
#  [0.68321745 0.23609447 0.08068808]
#  [0.6746467  0.24205412 0.08329918]
#  [0.68924009 0.23196899 0.07879092]
#  [0.68288241 0.23638374 0.08073385]
#  [0.2108604  0.50904497 0.28009464]
#  [0.21228178 0.50276048 0.28495774]
#  [0.19671318 0.5084026  0.29488423]
#  [0.21088727 0.47833854 0.31077418]
#  [0.20054889 0.50169356 0.29775755]
#  [0.19334027 0.48203939 0.32462033]
#  [0.19975267 0.50131358 0.29893375]
#  [0.27643535 0.46267851 0.26088614]
#  [0.2057952  0.50383954 0.29036525]
#  [0.21925391 0.47864605 0.30210005]
#  [0.23922468 0.46331722 0.2974581 ]
#  [0.21877326 0.49453266 0.28669407]
#  [0.22465283 0.48692153 0.28842564]
#  [0.19162176 0.49144173 0.31693651]
#  [0.27514568 0.47592345 0.24893087]
#  [0.22374147 0.50335893 0.27289961]
#  [0.19261498 0.48186395 0.32552106]
#  [0.22415674 0.48957998 0.28626328]
#  [0.19361869 0.48298779 0.32339352]
#  [0.22941757 0.48435076 0.28623167]
#  [0.18422632 0.48561003 0.33016366]
#  [0.23815949 0.49262467 0.26921584]
#  [0.18183923 0.48078697 0.3373738 ]
#  [0.19200136 0.48992614 0.31807249]
#  [0.22180683 0.49998774 0.27820543]
#  [0.21931997 0.50312629 0.27755374]
#  [0.19650249 0.50489071 0.2986068 ]
#  [0.18748301 0.50198961 0.31052737]
#  [0.19892691 0.49331759 0.3077555 ]
#  [0.28626428 0.47096621 0.24276951]
#  [0.23321666 0.4812285  0.28555484]
#  [0.24544378 0.4794928  0.27506342]
#  [0.23901146 0.4880292  0.27295933]
#  [0.1699028  0.46013899 0.3699582 ]
#  [0.18797583 0.47322663 0.33879754]
#  [0.20815294 0.49766306 0.294184  ]
#  [0.20343557 0.5064453  0.29011913]
#  [0.20266436 0.4917477  0.30558795]
#  [0.2231025  0.48859815 0.28829935]
#  [0.21521297 0.4823918  0.30239524]
#  [0.19212045 0.47300436 0.33487519]
#  [0.19820988 0.49531104 0.30647908]
#  [0.22662327 0.48914776 0.28422898]
#  [0.27545764 0.46371822 0.26082414]
#  [0.20755177 0.48506228 0.30738595]
#  [0.21880634 0.49019654 0.29099712]
#  [0.21462849 0.48982203 0.29554948]
#  [0.21785663 0.49804791 0.28409547]
#  [0.33951694 0.4424415  0.21804156]
#  [0.21979309 0.48944107 0.29076584]
#  [0.14626786 0.42756757 0.42616457]
#  [0.162747   0.44582442 0.39142858]
#  [0.16681884 0.47787634 0.35530482]
#  [0.16036982 0.44826058 0.3913696 ]
#  [0.15693017 0.44785607 0.39521376]
#  [0.15992404 0.45811235 0.38196362]
#  [0.16301194 0.42457059 0.41241748]
#  [0.16212387 0.45978672 0.37808941]
#  [0.16106216 0.43987668 0.39906116]
#  [0.16602482 0.48629265 0.34768253]
#  [0.18128324 0.49613999 0.32257677]
#  [0.16943669 0.46848161 0.3620817 ]
#  [0.17171656 0.48598    0.34230344]
#  [0.16106792 0.43775847 0.40117361]
#  [0.15914446 0.44987105 0.39098449]
#  [0.17108573 0.48286226 0.34605202]
#  [0.16839552 0.47209817 0.35950631]
#  [0.16405704 0.48286441 0.35307855]
#  [0.15222658 0.41512084 0.43265259]
#  [0.17108221 0.44342758 0.38549021]
#  [0.16859215 0.48471069 0.34669717]
#  [0.16569996 0.45218925 0.38211078]
#  [0.15932635 0.44801665 0.39265699]
#  [0.18125274 0.48605029 0.33269697]
#  [0.16723102 0.47810104 0.35466794]
#  [0.16875424 0.48461711 0.34662865]
#  [0.18431003 0.48883213 0.32685783]
#  [0.18101706 0.48537666 0.33360628]
#  [0.1597016  0.44945014 0.39084826]
#  [0.17280426 0.4905118  0.33668394]
#  [0.16733229 0.47511055 0.35755717]
#  [0.17223624 0.50589498 0.32186878]
#  [0.15895482 0.44914586 0.39189933]
#  [0.17741158 0.48036653 0.34222189]
#  [0.15584471 0.42131351 0.42284178]
#  [0.17033276 0.49371387 0.33595336]
#  [0.16117725 0.46385544 0.3749673 ]
#  [0.16739867 0.46963687 0.36296446]
#  [0.18321204 0.48557178 0.33121618]
#  [0.17649241 0.496795   0.32671259]
#  [0.16630094 0.47757527 0.35612379]
#  [0.18369599 0.50569429 0.31060971]
#  [0.162747   0.44582442 0.39142858]
#  [0.1616815  0.46668182 0.37163667]
#  [0.164695   0.47694381 0.35836118]
#  [0.17712231 0.4951571  0.32772058]
#  [0.17561441 0.47408678 0.3502988 ]
#  [0.17601478 0.48798674 0.33599847]
#  [0.16621754 0.4718508  0.36193166]
#  [0.16937039 0.46398141 0.3666482 ]]
# [[2.43852131e-03 4.56916082e-04 9.99939640e-01 ... 9.27512536e-01
#   9.97425825e-01 2.29350563e-03]
#  [3.65759725e-03 1.31926589e-03 9.99900423e-01 ... 9.01535785e-01
#   9.95612353e-01 3.25757561e-03]
#  [3.61550372e-03 8.69423794e-04 9.99865793e-01 ... 9.17457861e-01
#   9.95625983e-01 3.68765972e-03]
#  ...
#  [2.75780867e-03 1.02148161e-02 9.99999929e-01 ... 3.21423631e-02
#   8.37671759e-01 8.01847388e-05]
#  [2.84137678e-03 5.69333370e-03 9.99999937e-01 ... 2.50684153e-02
#   7.57411127e-01 6.97470539e-05]
#  [3.47095509e-03 1.08081027e-02 9.99999800e-01 ... 3.26096461e-02
#   7.44602426e-01 1.48545134e-04]]
# [[0.68610607 0.23277792 0.08111602]
#  [0.67164749 0.24264795 0.08570456]
#  [0.6804162  0.23673731 0.08284648]
#  [0.66127723 0.24964366 0.08907911]
#  [0.68692154 0.23222061 0.08085784]
#  [0.67859974 0.23781647 0.0835838 ]
#  [0.67599056 0.23965219 0.08435726]
#  [0.67645747 0.23934895 0.08419358]
#  [0.65979639 0.25070123 0.08950239]
#  [0.66829863 0.24495577 0.0867456 ]
#  [0.68816598 0.2313332  0.08050082]
#  [0.66579251 0.24655541 0.08765208]
#  [0.67148369 0.24284434 0.08567198]
#  [0.68390813 0.23468603 0.08140585]
#  [0.70679655 0.21850422 0.07469922]
#  [0.70039505 0.22288767 0.07671728]
#  [0.69858165 0.22417163 0.07724672]
#  [0.6850331  0.23348583 0.08148107]
#  [0.68155011 0.23582486 0.08262503]
#  [0.68562696 0.23305073 0.08132231]
#  [0.66819502 0.24492405 0.08688092]
#  [0.68240042 0.23524235 0.08235723]
#  [0.70046079 0.22305167 0.07648754]
#  [0.65436636 0.25418015 0.09145349]
#  [0.63616575 0.26630784 0.09752641]
#  [0.65685577 0.25257974 0.09056448]
#  [0.66619267 0.24623043 0.0875769 ]
#  [0.68159522 0.23583878 0.082566  ]
#  [0.68527651 0.23334314 0.08138035]
#  [0.65755836 0.25210661 0.09033503]
#  [0.65619315 0.2530266  0.09078025]
#  [0.67961785 0.23715721 0.08322495]
#  [0.69406694 0.22729431 0.07863876]
#  [0.70112365 0.22241292 0.07646343]
#  [0.66675588 0.24593607 0.08730805]
#  [0.68964564 0.23041261 0.07994176]
#  [0.69511072 0.22659074 0.07829855]
#  [0.68680089 0.23235541 0.0808437 ]
#  [0.6709211  0.24324752 0.08583139]
#  [0.67790421 0.23836116 0.08373463]
#  [0.68918524 0.23066538 0.08014937]
#  [0.64915801 0.25754673 0.09329526]
#  [0.67613069 0.23970086 0.08416845]
#  [0.66605677 0.24629873 0.0876445 ]
#  [0.6546522  0.25395939 0.09138841]
#  [0.66850805 0.24472741 0.08676454]
#  [0.68090992 0.2362779  0.08281218]
#  [0.67219135 0.24230607 0.08550258]
#  [0.68702688 0.23211586 0.08085726]
#  [0.68055659 0.23658192 0.0828615 ]
#  [0.20448073 0.50937589 0.28614339]
#  [0.20587447 0.50322313 0.29090239]
#  [0.19076811 0.50865828 0.30057361]
#  [0.20436488 0.47946229 0.31617282]
#  [0.19443715 0.50219758 0.30336527]
#  [0.18745525 0.48276383 0.32978092]
#  [0.19372155 0.50167366 0.30460478]
#  [0.26878038 0.46428374 0.26693588]
#  [0.19955178 0.50429569 0.29615253]
#  [0.21261632 0.479571   0.30781268]
#  [0.23196066 0.46492342 0.30311592]
#  [0.21217948 0.49521773 0.29260279]
#  [0.21774828 0.48808498 0.29416673]
#  [0.18581728 0.4920264  0.32215632]
#  [0.26749578 0.47733662 0.2551676 ]
#  [0.21700505 0.5039395  0.27905545]
#  [0.1867541  0.4824915  0.3307544 ]
#  [0.2174388  0.49044362 0.29211758]
#  [0.18754991 0.48419112 0.32825897]
#  [0.22252384 0.48540159 0.29207457]
#  [0.17865186 0.48613622 0.33521192]
#  [0.23108374 0.49356535 0.27535091]
#  [0.17628516 0.48183661 0.34187823]
#  [0.18618474 0.49057492 0.32324034]
#  [0.21512002 0.50064429 0.28423569]
#  [0.21269344 0.50368872 0.28361784]
#  [0.19052746 0.50530864 0.30416389]
#  [0.18183235 0.50238069 0.31578696]
#  [0.19287973 0.49390229 0.31321798]
#  [0.27845163 0.47257121 0.24897716]
#  [0.22621265 0.48238961 0.29139775]
#  [0.23820517 0.48076226 0.28103257]
#  [0.23193318 0.48905194 0.27901488]
#  [0.1647747  0.46133908 0.37388622]
#  [0.18223575 0.47389034 0.3438739 ]
#  [0.20187702 0.49811897 0.30000402]
#  [0.19727431 0.50678861 0.29593708]
#  [0.19636715 0.49269391 0.31093893]
#  [0.21643222 0.48937235 0.29419543]
#  [0.20864133 0.4833658  0.30799288]
#  [0.18623128 0.47391046 0.33985826]
#  [0.19220947 0.49582639 0.31196414]
#  [0.21979823 0.49008672 0.29011506]
#  [0.26776369 0.46536987 0.26686644]
#  [0.20123165 0.4858604  0.31290795]
#  [0.21225076 0.49091329 0.29683595]
#  [0.20815387 0.49054273 0.30130339]
#  [0.21128356 0.49869763 0.29001881]
#  [0.33142856 0.444537   0.22403445]
#  [0.2131697  0.49024449 0.29658581]
#  [0.14192825 0.42903588 0.42903588]
#  [0.15778981 0.44715523 0.39505496]
#  [0.16195537 0.47906075 0.35898389]
#  [0.15563043 0.44968548 0.3946841 ]
#  [0.15231799 0.44939513 0.39828688]
#  [0.15538097 0.46011053 0.3845085 ]
#  [0.1578136  0.42565931 0.41652709]
#  [0.1574665  0.46159757 0.38093593]
#  [0.15625563 0.44212666 0.40161771]
#  [0.16123501 0.48706457 0.35170042]
#  [0.17584818 0.49657713 0.32757469]
#  [0.16435286 0.46975171 0.36589543]
#  [0.16663383 0.48682542 0.34654075]
#  [0.15608086 0.43934387 0.40457527]
#  [0.15426477 0.45117294 0.39456229]
#  [0.16598573 0.48358787 0.3504264 ]
#  [0.16342418 0.47312597 0.36344985]
#  [0.15943718 0.48381181 0.35675101]
#  [0.14778923 0.41868957 0.4335212 ]
#  [0.16576411 0.44541369 0.3888222 ]
#  [0.16364941 0.48555579 0.35079481]
#  [0.16061756 0.45326532 0.38611713]
#  [0.15477293 0.45051999 0.39470708]
#  [0.17574547 0.48687839 0.33737614]
#  [0.16233884 0.47895958 0.35870158]
#  [0.16387229 0.48551699 0.35061072]
#  [0.17870829 0.48952919 0.33176253]
#  [0.17555034 0.48601765 0.33843202]
#  [0.15495458 0.4510485  0.39399692]
#  [0.16774435 0.49131191 0.34094374]
#  [0.16245039 0.47662142 0.36092819]
#  [0.16729124 0.50613682 0.32657194]
#  [0.15422171 0.4507713  0.39500699]
#  [0.17208345 0.48123499 0.34668156]
#  [0.15117708 0.42318694 0.42563598]
#  [0.16536473 0.49463854 0.33999673]
#  [0.15641105 0.46481366 0.37877529]
#  [0.16246145 0.47061538 0.36692317]
#  [0.17766089 0.48619414 0.33614497]
#  [0.17124903 0.49732804 0.33142293]
#  [0.161396   0.47859677 0.36000723]
#  [0.17816427 0.50601428 0.31582145]
#  [0.15778981 0.44715523 0.39505496]
#  [0.15697904 0.46791949 0.37510147]
#  [0.15986103 0.47789563 0.36224334]
#  [0.17181059 0.49576253 0.33242688]
#  [0.17024678 0.47534086 0.35441236]
#  [0.17074922 0.48868203 0.34056875]
#  [0.16127172 0.47261919 0.36610909]
#  [0.16427417 0.46489309 0.37083274]]

# %%
import matplotlib.pyplot as plt

range_x = range(0, n_iter, 1)

plt.figure(figsize=(10, 6))
plt.plot(range_x, accuracy_values, marker='o', linestyle='-', color='b', label='Accuracy')
plt.title('Model Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('N iterations')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# **e)** How high of an accuracy is it possible to acheive with a neural network on this dataset, if we use the whole thing as training data?

# %% [markdown]
# With high number of iterations I would expect accuracy -> 100% (approaching) as we train and test on the same data and train data set 'have seen' test data. We can not rely on this results and expect to get the same hig accuracy for new training set that was not part of training.
